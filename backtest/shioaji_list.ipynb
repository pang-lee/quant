# %%
# coding: utf-8
import pandas as pd
from datetime import datetime, timedelta
from dotenv import load_dotenv
load_dotenv()
import os
import shioaji as sj

api = sj.Shioaji()
api.login(
    api_key=os.getenv('API_KEY1'),
    secret_key=os.getenv('SECRET_KEY1'),
    fetch_contract=False,
)
api.fetch_contracts(contract_download=True)
# Out:
# Response Code: 0 | Event Code: 0 | Info: host '210.59.255.161:80', IP 210.59.255.161:80 (host 1 of 1) (host connection attempt 1 of 1) (total connection attempt 1 of 1) | Event: Session up

# %%
api.usage()
# Out:
# UsageStatus(connections=2, bytes=377699446, limit_bytes=524288000, remaining_bytes=146588554)

# %% [markdown]
# ### 獲取資料

# %%
# https://ithelp.ithome.com.tw/articles/10280898 教學參考
def get_shioaji_index_data(begin, end, id, type='1k'):
    # 將 begin 和 end 轉換為所需的格式 2024_0708
    begin_month = begin[:7].replace('-', '')  # 取得2024-07部分，變成202407
    end_month = end[:7].replace('-', '')      # 取得2024-08部分，變成202408
    folder_name = f"{begin[:4]}_{begin_month[4:6]}{end_month[4:6]}"  # 2024_0708
    
    # 定義路徑
    folder_path = f"./index_data/shioaji/{folder_name}/"
    
    # 如果資料夾不存在，則創建
    if not os.path.exists(folder_path):
        os.makedirs(folder_path)
        
    # 定義CSV檔案的名稱
    file_name = f"{id}"
    file_path = os.path.join(folder_path, file_name)
    
    #如果要查看合約代號可以直接print(api.Contracts), 查看特定的股票可以print(api.Contracts.Stocks.TSE['2330'])
    # 創建一個空的 DataFrame 來存儲所有數據
    all_ticks = pd.DataFrame()

    if type == '1k':
        print('Remain usage API usage:', api.usage())
            
        # 調用 API 獲取當天的數據
        kbars = api.kbars(
            contract=api.Contracts.Stocks[id],
            start=begin,
            end=end,
        )
            
        df = pd.DataFrame({**kbars})
        all_ticks = pd.concat([all_ticks, df], ignore_index=True)
        
        print(f"Processed data from {begin} to {end}")
        
        all_ticks['ts'] = pd.to_datetime(all_ticks['ts'])

        all_ticks.to_csv(f"{file_path}k.csv", index=False)
        print(f'Data saved to {file_path}')
        
    elif type == 'tick':
        # 將 begin 和 end 轉換為 datetime 對象
        start_date = datetime.strptime(begin, "%Y-%m-%d")
        end_date = datetime.strptime(end, "%Y-%m-%d")
    
        # 循環日期範圍
        current_date = start_date
        while current_date <= end_date:
            date_str = current_date.strftime("%Y-%m-%d")
            print(f"Fetching data for {date_str}..., Remain usage API usage: {api.usage()}")
            
            try:
                # 調用 API 獲取當日數據
                ticks = api.ticks(
                    contract=api.Contracts.Stocks[id],
                    date=date_str
                )
                df = pd.DataFrame({**ticks})
            
                if not df.empty:
                    # 合併當天數據到總表
                    all_ticks = pd.concat([all_ticks, df], ignore_index=True)
                    print(f"Data for {date_str} processed.")
                else:
                    print(f"No data available for {date_str}.")
        
            except Exception as e:
                print(f"Error fetching data for {date_str}: {e}")
        
            # 日期增加一天
            current_date += timedelta(days=1)   
        
        all_ticks['ts'] = pd.to_datetime(all_ticks['ts'])
        all_ticks.to_csv(f"{file_path}.csv", index=False)
        print(f"Data saved to {file_path}")
        
    elif type == 'future-k':
        # 循環日期範圍
        print(f"Fetching data for {begin}, {end}..., Remain usage API usage: {api.usage()}")
        
        try:
            # 調用 API 獲取當日數據
            ticks = api.kbars(
                contract=api.Contracts.Futures[id],
                start=begin,
                end=end
            )
            df = pd.DataFrame({**ticks})
            
            if not df.empty:
                # 合併當天數據到總表
                all_ticks = pd.concat([all_ticks, df], ignore_index=True)
                print(f"Data for {begin}, {end} processed.")
            else:
                print(f"No data available for {begin}, {end}.")
        
        except Exception as e:
            print(f"Error fetching data for {begin}, {end}: {e}")
        
        all_ticks['ts'] = pd.to_datetime(all_ticks['ts'])
        all_ticks.to_csv(f"{file_path}k.csv", index=False)
        print(f"Data saved to {file_path}")
   
    elif type == 'future-t':
        # 將 begin 和 end 轉換為 datetime 對象
        start_date = datetime.strptime(begin, "%Y-%m-%d")
        end_date = datetime.strptime(end, "%Y-%m-%d")
    
        # 循環日期範圍
        current_date = start_date
        while current_date <= end_date:
            date_str = current_date.strftime("%Y-%m-%d")
            print(f"Fetching data for {date_str}..., Remain usage API usage: {api.usage()}")
            
            try:
                # 調用 API 獲取當日數據
                ticks = api.ticks(
                    contract=api.Contracts.Futures[id],
                    date=date_str
                )
                df = pd.DataFrame({**ticks})
            
                if not df.empty:
                    # 合併當天數據到總表
                    all_ticks = pd.concat([all_ticks, df], ignore_index=True)
                    print(f"Data for {date_str} processed.")
                else:
                    print(f"No data available for {date_str}.")
        
            except Exception as e:
                print(f"Error fetching data for {date_str}: {e}")
        
            # 日期增加一天
            current_date += timedelta(days=1)
        
        all_ticks['ts'] = pd.to_datetime(all_ticks['ts'])
        all_ticks.to_csv(f"{file_path}.csv", index=False)
        print(f"Data saved to {file_path}")

    elif type == 'index-t':
        # 設置開始日期和結束日期
        start_date, end_date = datetime.strptime(begin, "%Y-%m-%d"), datetime.strptime(end, "%Y-%m-%d")
        
        # 遍歷日期範圍，按天調用 API
        current_date = start_date
        
        while current_date <= end_date:
            print('Remain usage API usage:', api.usage())

            # 格式化日期為字符串
            date_str = current_date.strftime("%Y-%m-%d")

            # 調用 API 獲取當天的數據 TSE001(大盤), TSE099(台灣50)
            ticks = api.ticks(
                contract=api.Contracts.Indexs.TSE.TSE001,
                date=date_str
            )

            df = pd.DataFrame({**ticks})
            all_ticks = pd.concat([all_ticks, df], ignore_index=True)

            print(f"Processed data for {date_str}")

            current_date += timedelta(days=1)

        all_ticks = all_ticks[['ts', 'close']]
        all_ticks['ts'] = pd.to_datetime(all_ticks['ts'])

        all_ticks.to_csv(f"{file_path}.csv", index=False)
        print(f'Data saved to {file_path}')

    elif type == 'index-k':
        # 循環日期範圍
        print(f"Fetching data for {begin}, {end}..., Remain usage API usage: {api.usage()}")
        
        try:
            # 調用 API 獲取當日數據
            ticks = api.kbars(
                contract=api.Contracts.Indexs.TSE.TSE001,
                start=begin,
                end=end
            )
            df = pd.DataFrame({**ticks})
            
            if not df.empty:
                # 合併當天數據到總表
                all_ticks = pd.concat([all_ticks, df], ignore_index=True)
                print(f"Data for {begin}, {end} processed.")
            else:
                print(f"No data available for {begin}, {end}.")
        
        except Exception as e:
            print(f"Error fetching data for {begin}, {end}: {e}")
        
        all_ticks['ts'] = pd.to_datetime(all_ticks['ts'])
        all_ticks.to_csv(f"{file_path}k.csv", index=False)
        print(f"Data saved to {file_path}")

    return

# %%
# get_shioaji_index_data('2025-04-01', '2025-06-06', '2881', type='tick')
# get_shioaji_index_data('2025-04-01', '2025-06-06', '2881', type='1k')
# get_shioaji_index_data('2025-04-01', '2025-06-06', '2882', type='tick')
# get_shioaji_index_data('2025-04-01', '2025-06-06', '2882', type='1k')

# get_shioaji_index_data('2025-04-01', '2025-05-30', 'TSE001', type='index-t')
# get_shioaji_index_data('2025-04-01', '2025-05-30', 'TSE001', type='index-k')

# get_shioaji_index_data('2025-04-01', '2025-06-05', 'TMFR1', type='future-t')
# get_shioaji_index_data('2025-04-01', '2025-06-05', 'TMFR1', type='future-k')
get_shioaji_index_data('2025-04-01', '2025-06-05', 'MXFR1', type='future-t')
get_shioaji_index_data('2025-04-01', '2025-06-05', 'MXFR1', type='future-k')
# Out:
# Fetching data for 2025-04-01..., Remain usage API usage: connections=2 bytes=28856726 limit_bytes=524288000 remaining_bytes=495431274
# Data for 2025-04-01 processed.
# Fetching data for 2025-04-02..., Remain usage API usage: connections=2 bytes=28858505 limit_bytes=524288000 remaining_bytes=495429495
# Data for 2025-04-02 processed.
# Fetching data for 2025-04-03..., Remain usage API usage: connections=1 bytes=36116729 limit_bytes=524288000 remaining_bytes=488171271
# Data for 2025-04-03 processed.
# Fetching data for 2025-04-04..., Remain usage API usage: connections=1 bytes=43030317 limit_bytes=524288000 remaining_bytes=481257683
# No data available for 2025-04-04.
# Fetching data for 2025-04-05..., Remain usage API usage: connections=1 bytes=43030317 limit_bytes=524288000 remaining_bytes=481257683
# Data for 2025-04-05 processed.
# Fetching data for 2025-04-06..., Remain usage API usage: connections=1 bytes=47918450 limit_bytes=524288000 remaining_bytes=476369550
# Data for 2025-04-06 processed.
# Fetching data for 2025-04-07..., Remain usage API usage: connections=1 bytes=52804727 limit_bytes=524288000 remaining_bytes=471483273
# Data for 2025-04-07 processed.
# Fetching data for 2025-04-08..., Remain usage API usage: connections=1 bytes=52804727 limit_bytes=524288000 remaining_bytes=471483273
# Data for 2025-04-08 processed.
# Fetching data for 2025-04-09..., Remain usage API usage: connections=1 bytes=57761126 limit_bytes=524288000 remaining_bytes=466526874
# Data for 2025-04-09 processed.
# Fetching data for 2025-04-10..., Remain usage API usage: connections=1 bytes=76751759 limit_bytes=524288000 remaining_bytes=447536241
# Data for 2025-04-10 processed.
# Fetching data for 2025-04-11..., Remain usage API usage: connections=1 bytes=94551050 limit_bytes=524288000 remaining_bytes=429736950
# Data for 2025-04-11 processed.
# Fetching data for 2025-04-12..., Remain usage API usage: connections=1 bytes=105488804 limit_bytes=524288000 remaining_bytes=418799196
# Data for 2025-04-12 processed.
# Fetching data for 2025-04-13..., Remain usage API usage: connections=1 bytes=123214096 limit_bytes=524288000 remaining_bytes=401073904
# No data available for 2025-04-13.
# Fetching data for 2025-04-14..., Remain usage API usage: connections=1 bytes=123214096 limit_bytes=524288000 remaining_bytes=401073904
# Data for 2025-04-14 processed.
# Fetching data for 2025-04-15..., Remain usage API usage: connections=1 bytes=130744560 limit_bytes=524288000 remaining_bytes=393543440
# Data for 2025-04-15 processed.
# Fetching data for 2025-04-16..., Remain usage API usage: connections=1 bytes=143035930 limit_bytes=524288000 remaining_bytes=381252070
# Data for 2025-04-16 processed.
# Fetching data for 2025-04-17..., Remain usage API usage: connections=1 bytes=150031460 limit_bytes=524288000 remaining_bytes=374256540
# Data for 2025-04-17 processed.
# Fetching data for 2025-04-18..., Remain usage API usage: connections=1 bytes=155209198 limit_bytes=524288000 remaining_bytes=369078802
# Data for 2025-04-18 processed.
# Fetching data for 2025-04-19..., Remain usage API usage: connections=1 bytes=163303506 limit_bytes=524288000 remaining_bytes=360984494
# Data for 2025-04-19 processed.
# Fetching data for 2025-04-20..., Remain usage API usage: connections=1 bytes=170074274 limit_bytes=524288000 remaining_bytes=354213726
# No data available for 2025-04-20.
# Fetching data for 2025-04-21..., Remain usage API usage: connections=1 bytes=170074274 limit_bytes=524288000 remaining_bytes=354213726
# Data for 2025-04-21 processed.
# Fetching data for 2025-04-22..., Remain usage API usage: connections=1 bytes=170074274 limit_bytes=524288000 remaining_bytes=354213726
# Data for 2025-04-22 processed.
# Fetching data for 2025-04-23..., Remain usage API usage: connections=1 bytes=173945451 limit_bytes=524288000 remaining_bytes=350342549
# Data for 2025-04-23 processed.
# Fetching data for 2025-04-24..., Remain usage API usage: connections=1 bytes=180128627 limit_bytes=524288000 remaining_bytes=344159373
# Data for 2025-04-24 processed.
# Fetching data for 2025-04-25..., Remain usage API usage: connections=1 bytes=186660388 limit_bytes=524288000 remaining_bytes=337627612
# Data for 2025-04-25 processed.
# Fetching data for 2025-04-26..., Remain usage API usage: connections=1 bytes=193531711 limit_bytes=524288000 remaining_bytes=330756289
# Data for 2025-04-26 processed.
# Fetching data for 2025-04-27..., Remain usage API usage: connections=1 bytes=200252407 limit_bytes=524288000 remaining_bytes=324035593
# No data available for 2025-04-27.
# Fetching data for 2025-04-28..., Remain usage API usage: connections=1 bytes=200252407 limit_bytes=524288000 remaining_bytes=324035593
# Data for 2025-04-28 processed.
# Fetching data for 2025-04-29..., Remain usage API usage: connections=1 bytes=204165593 limit_bytes=524288000 remaining_bytes=320122407
# Data for 2025-04-29 processed.
# Fetching data for 2025-04-30..., Remain usage API usage: connections=1 bytes=210226480 limit_bytes=524288000 remaining_bytes=314061520
# Data for 2025-04-30 processed.
# Fetching data for 2025-05-01..., Remain usage API usage: connections=1 bytes=215507235 limit_bytes=524288000 remaining_bytes=308780765
# Data for 2025-05-01 processed.
# Fetching data for 2025-05-02..., Remain usage API usage: connections=1 bytes=220554088 limit_bytes=524288000 remaining_bytes=303733912
# Data for 2025-05-02 processed.
# Fetching data for 2025-05-03..., Remain usage API usage: connections=1 bytes=224596382 limit_bytes=524288000 remaining_bytes=299691618
# Data for 2025-05-03 processed.
# Fetching data for 2025-05-04..., Remain usage API usage: connections=1 bytes=224596382 limit_bytes=524288000 remaining_bytes=299691618
# No data available for 2025-05-04.
# Fetching data for 2025-05-05..., Remain usage API usage: connections=1 bytes=224596382 limit_bytes=524288000 remaining_bytes=299691618
# Data for 2025-05-05 processed.
# Fetching data for 2025-05-06..., Remain usage API usage: connections=1 bytes=230340497 limit_bytes=524288000 remaining_bytes=293947503
# Data for 2025-05-06 processed.
# Fetching data for 2025-05-07..., Remain usage API usage: connections=1 bytes=237580891 limit_bytes=524288000 remaining_bytes=286707109
# Data for 2025-05-07 processed.
# Fetching data for 2025-05-08..., Remain usage API usage: connections=1 bytes=250021539 limit_bytes=524288000 remaining_bytes=274266461
# Data for 2025-05-08 processed.
# Fetching data for 2025-05-09..., Remain usage API usage: connections=1 bytes=250023318 limit_bytes=524288000 remaining_bytes=274264682
# Data for 2025-05-09 processed.
# Fetching data for 2025-05-10..., Remain usage API usage: connections=1 bytes=256584961 limit_bytes=524288000 remaining_bytes=267703039
# Data for 2025-05-10 processed.
# Fetching data for 2025-05-11..., Remain usage API usage: connections=1 bytes=256584961 limit_bytes=524288000 remaining_bytes=267703039
# No data available for 2025-05-11.
# Fetching data for 2025-05-12..., Remain usage API usage: connections=1 bytes=256584961 limit_bytes=524288000 remaining_bytes=267703039
# Data for 2025-05-12 processed.
# Fetching data for 2025-05-13..., Remain usage API usage: connections=1 bytes=265115324 limit_bytes=524288000 remaining_bytes=259172676
# Data for 2025-05-13 processed.
# Fetching data for 2025-05-14..., Remain usage API usage: connections=1 bytes=269953272 limit_bytes=524288000 remaining_bytes=254334728
# Data for 2025-05-14 processed.
# Fetching data for 2025-05-15..., Remain usage API usage: connections=1 bytes=275781962 limit_bytes=524288000 remaining_bytes=248506038
# Data for 2025-05-15 processed.
# Fetching data for 2025-05-16..., Remain usage API usage: connections=1 bytes=280868394 limit_bytes=524288000 remaining_bytes=243419606
# Data for 2025-05-16 processed.
# Fetching data for 2025-05-17..., Remain usage API usage: connections=1 bytes=285404655 limit_bytes=524288000 remaining_bytes=238883345
# Data for 2025-05-17 processed.
# Fetching data for 2025-05-18..., Remain usage API usage: connections=1 bytes=285404655 limit_bytes=524288000 remaining_bytes=238883345
# No data available for 2025-05-18.
# Fetching data for 2025-05-19..., Remain usage API usage: connections=1 bytes=285404655 limit_bytes=524288000 remaining_bytes=238883345
# Data for 2025-05-19 processed.
# Fetching data for 2025-05-20..., Remain usage API usage: connections=1 bytes=291749449 limit_bytes=524288000 remaining_bytes=232538551
# Data for 2025-05-20 processed.
# Fetching data for 2025-05-21..., Remain usage API usage: connections=1 bytes=296409288 limit_bytes=524288000 remaining_bytes=227878712
# Data for 2025-05-21 processed.
# Fetching data for 2025-05-22..., Remain usage API usage: connections=1 bytes=300722940 limit_bytes=524288000 remaining_bytes=223565060
# Data for 2025-05-22 processed.
# Fetching data for 2025-05-23..., Remain usage API usage: connections=1 bytes=303927963 limit_bytes=524288000 remaining_bytes=220360037
# Data for 2025-05-23 processed.
# Fetching data for 2025-05-24..., Remain usage API usage: connections=1 bytes=308668896 limit_bytes=524288000 remaining_bytes=215619104
# Data for 2025-05-24 processed.
# Fetching data for 2025-05-25..., Remain usage API usage: connections=1 bytes=308668896 limit_bytes=524288000 remaining_bytes=215619104
# No data available for 2025-05-25.
# Fetching data for 2025-05-26..., Remain usage API usage: connections=1 bytes=308668896 limit_bytes=524288000 remaining_bytes=215619104
# Data for 2025-05-26 processed.
# Fetching data for 2025-05-27..., Remain usage API usage: connections=1 bytes=317662889 limit_bytes=524288000 remaining_bytes=206625111
# Data for 2025-05-27 processed.
# Fetching data for 2025-05-28..., Remain usage API usage: connections=1 bytes=323998959 limit_bytes=524288000 remaining_bytes=200289041
# Data for 2025-05-28 processed.
# Fetching data for 2025-05-29..., Remain usage API usage: connections=1 bytes=327478886 limit_bytes=524288000 remaining_bytes=196809114
# Data for 2025-05-29 processed.
# Fetching data for 2025-05-30..., Remain usage API usage: connections=1 bytes=332552017 limit_bytes=524288000 remaining_bytes=191735983
# Data for 2025-05-30 processed.
# Fetching data for 2025-05-31..., Remain usage API usage: connections=1 bytes=337538864 limit_bytes=524288000 remaining_bytes=186749136
# No data available for 2025-05-31.
# Fetching data for 2025-06-01..., Remain usage API usage: connections=1 bytes=337538864 limit_bytes=524288000 remaining_bytes=186749136
# Data for 2025-06-01 processed.
# Fetching data for 2025-06-02..., Remain usage API usage: connections=1 bytes=337538864 limit_bytes=524288000 remaining_bytes=186749136
# Data for 2025-06-02 processed.
# Fetching data for 2025-06-03..., Remain usage API usage: connections=1 bytes=344284600 limit_bytes=524288000 remaining_bytes=180003400
# Data for 2025-06-03 processed.
# Fetching data for 2025-06-04..., Remain usage API usage: connections=1 bytes=347045346 limit_bytes=524288000 remaining_bytes=177242654
# Data for 2025-06-04 processed.
# Fetching data for 2025-06-05..., Remain usage API usage: connections=1 bytes=351977667 limit_bytes=524288000 remaining_bytes=172310333
# Data for 2025-06-05 processed.
# Data saved to ./index_data/shioaji/2025_0406/MXFR1
# Fetching data for 2025-04-01, 2025-06-05..., Remain usage API usage: connections=1 bytes=360534789 limit_bytes=524288000 remaining_bytes=163753211
# Data for 2025-04-01, 2025-06-05 processed.
# Data saved to ./index_data/shioaji/2025_0406/MXFR1

# %%
api.logout()
# Out:
# True

# %% [markdown]
# ### 查看合約與指數

# %%
# 遍歷所有期貨代碼
for future_code in dir(api.Contracts.Futures):
    # 排除內建屬性和方法，只保留商品代碼
    if not future_code.startswith('__'):
        try:
            # 構建近月合約的完整代碼 (例如 FZ1.FZ1R1)
            contract = getattr(api.Contracts.Futures, future_code)
            near_month_code = f"{future_code}R1"
            future_detail = getattr(contract, near_month_code)
            
            # 打印詳細資訊
            print(f"商品代碼: {future_detail.code}")
            print(f"符號: {future_detail.symbol}")
            print(f"名稱: {future_detail.name}")
            print(f"類別: {future_detail.category}")
            print(f"交割月份: {future_detail.delivery_month}")
            print(f"交割日期: {future_detail.delivery_date}")
            print(f"標的種類: {future_detail.underlying_kind}")
            print(f"標的代碼: {future_detail.underlying_code}")
            print(f"單位: {future_detail.unit}")
            print(f"漲停價: {future_detail.limit_up}")
            print(f"跌停價: {future_detail.limit_down}")
            print(f"參考價: {future_detail.reference}")
            print(f"更新日期: {future_detail.update_date}")
            print(f"目標代碼: {future_detail.target_code}")
            print("-" * 50)  # 分隔線
            
        except AttributeError:
            # 如果某個代碼沒有 R1 合約，跳過並繼續
            print(f"{future_code} 沒有近月合約數據")
            continue
        except Exception as e:
            # 處理其他可能的錯誤
            print(f"處理 {future_code} 時發生錯誤: {str(e)}")
            continue
# Out:
# 商品代碼: BRFR1
# 符號: BRFR1
# 名稱: 布蘭特原油期貨近月
# 類別: BRF
# 交割月份: 202504
# 交割日期: 2025/04/02
# 標的種類: C
# 標的代碼:
# 單位: 1
# 漲停價: 2431.0
# 跌停價: 2200.0
# 參考價: 2315.5
# 更新日期: 2025/03/20
# 目標代碼: BRFE5
# --------------------------------------------------
# 商品代碼: BTFR1
# 符號: BTFR1
# 名稱: 臺灣生技期貨近月
# 類別: BTF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: I
# 標的代碼:
# 單位: 1
# 漲停價: 4259.0
# 跌停價: 3485.0
# 參考價: 3872.0
# 更新日期: 2025/03/20
# 目標代碼: BTFD5
# --------------------------------------------------
# 商品代碼: CAFR1
# 符號: CAFR1
# 名稱: 南亞期貨近月
# 類別: CAF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 1303
# 單位: 1
# 漲停價: 37.6
# 跌停價: 30.8
# 參考價: 34.2
# 更新日期: 2025/03/20
# 目標代碼: CAFD5
# --------------------------------------------------
# 商品代碼: CBFR1
# 符號: CBFR1
# 名稱: 中鋼期貨近月
# 類別: CBF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2002
# 單位: 1
# 漲停價: 26.45
# 跌停價: 21.65
# 參考價: 24.05
# 更新日期: 2025/03/20
# 目標代碼: CBFD5
# --------------------------------------------------
# 商品代碼: CCFR1
# 符號: CCFR1
# 名稱: 聯電期貨近月
# 類別: CCF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2303
# 單位: 1
# 漲停價: 49.0
# 跌停價: 40.1
# 參考價: 44.55
# 更新日期: 2025/03/20
# 目標代碼: CCFD5
# --------------------------------------------------
# 商品代碼: CDFR1
# 符號: CDFR1
# 名稱: 台積電期貨近月
# 類別: CDF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2330
# 單位: 1
# 漲停價: 1050.0
# 跌停價: 862.0
# 參考價: 957.0
# 更新日期: 2025/03/20
# 目標代碼: CDFD5
# --------------------------------------------------
# 商品代碼: CE1R1
# 符號: CE1R1
# 名稱: 富邦金期貨近月
# 類別: CE1
# 交割月份: 202506
# 交割日期: 2025/06/18
# 標的種類: S
# 標的代碼: 2881
# 單位: 1
# 漲停價: 98.0
# 跌停價: 80.2
# 參考價: 89.1
# 更新日期: 2025/03/20
# 目標代碼: CE1F5
# --------------------------------------------------
# 商品代碼: CEFR1
# 符號: CEFR1
# 名稱: 富邦金期貨近月
# 類別: CEF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2881
# 單位: 1
# 漲停價: 98.5
# 跌停價: 80.7
# 參考價: 89.6
# 更新日期: 2025/03/20
# 目標代碼: CEFD5
# --------------------------------------------------
# 商品代碼: CFFR1
# 符號: CFFR1
# 名稱: 台塑期貨近月
# 類別: CFF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 1301
# 單位: 1
# 漲停價: 44.35
# 跌停價: 36.35
# 參考價: 40.35
# 更新日期: 2025/03/20
# 目標代碼: CFFD5
# --------------------------------------------------
# 商品代碼: CGFR1
# 符號: CGFR1
# 名稱: 仁寶期貨近月
# 類別: CGF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2324
# 單位: 1
# 漲停價: 40.95
# 跌停價: 33.55
# 參考價: 37.25
# 更新日期: 2025/03/20
# 目標代碼: CGFD5
# --------------------------------------------------
# 商品代碼: CHFR1
# 符號: CHFR1
# 名稱: 友達期貨近月
# 類別: CHF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2409
# 單位: 1
# 漲停價: 16.9
# 跌停價: 13.9
# 參考價: 15.4
# 更新日期: 2025/03/20
# 目標代碼: CHFD5
# --------------------------------------------------
# 商品代碼: CJFR1
# 符號: CJFR1
# 名稱: 華南金期貨近月
# 類別: CJF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2880
# 單位: 1
# 漲停價: 30.9
# 跌停價: 25.3
# 參考價: 28.1
# 更新日期: 2025/03/20
# 目標代碼: CJFD5
# --------------------------------------------------
# 商品代碼: CKFR1
# 符號: CKFR1
# 名稱: 國泰金期貨近月
# 類別: CKF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2882
# 單位: 1
# 漲停價: 72.3
# 跌停價: 59.3
# 參考價: 65.8
# 更新日期: 2025/03/20
# 目標代碼: CKFD5
# --------------------------------------------------
# 商品代碼: CLFR1
# 符號: CLFR1
# 名稱: 兆豐金期貨近月
# 類別: CLF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2886
# 單位: 1
# 漲停價: 43.8
# 跌停價: 35.9
# 參考價: 39.85
# 更新日期: 2025/03/20
# 目標代碼: CLFD5
# --------------------------------------------------
# 商品代碼: CMFR1
# 符號: CMFR1
# 名稱: 台新金期貨近月
# 類別: CMF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2887
# 單位: 1
# 漲停價: 19.3
# 跌停價: 15.8
# 參考價: 17.55
# 更新日期: 2025/03/20
# 目標代碼: CMFD5
# --------------------------------------------------
# 商品代碼: CNFR1
# 符號: CNFR1
# 名稱: 中信金期貨近月
# 類別: CNF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2891
# 單位: 1
# 漲停價: 44.35
# 跌停價: 36.35
# 參考價: 40.35
# 更新日期: 2025/03/20
# 目標代碼: CNFD5
# --------------------------------------------------
# 商品代碼: CQFR1
# 符號: CQFR1
# 名稱: 統一期貨近月
# 類別: CQF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 1216
# 單位: 1
# 漲停價: 89.2
# 跌停價: 73.0
# 參考價: 81.1
# 更新日期: 2025/03/20
# 目標代碼: CQFD5
# --------------------------------------------------
# 商品代碼: CRFR1
# 符號: CRFR1
# 名稱: 遠東新期貨近月
# 類別: CRF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 1402
# 單位: 1
# 漲停價: 37.4
# 跌停價: 30.6
# 參考價: 34.0
# 更新日期: 2025/03/20
# 目標代碼: CRFD5
# --------------------------------------------------
# 商品代碼: CSFR1
# 符號: CSFR1
# 名稱: 華新期貨近月
# 類別: CSF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 1605
# 單位: 1
# 漲停價: 29.3
# 跌停價: 24.0
# 參考價: 26.65
# 更新日期: 2025/03/20
# 目標代碼: CSFD5
# --------------------------------------------------
# 商品代碼: CUFR1
# 符號: CUFR1
# 名稱: 中環期貨近月
# 類別: CUF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2323
# 單位: 1
# 漲停價: 10.8
# 跌停價: 8.85
# 參考價: 9.83
# 更新日期: 2025/03/20
# 目標代碼: CUFD5
# --------------------------------------------------
# 商品代碼: CWFR1
# 符號: CWFR1
# 名稱: 佳世達期貨近月
# 類別: CWF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2352
# 單位: 1
# 漲停價: 34.95
# 跌停價: 28.65
# 參考價: 31.8
# 更新日期: 2025/03/20
# 目標代碼: CWFD5
# --------------------------------------------------
# 商品代碼: CXFR1
# 符號: CXFR1
# 名稱: 大同期貨近月
# 類別: CXF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2371
# 單位: 1
# 漲停價: 48.75
# 跌停價: 39.95
# 參考價: 44.35
# 更新日期: 2025/03/20
# 目標代碼: CXFD5
# --------------------------------------------------
# 商品代碼: CYFR1
# 符號: CYFR1
# 名稱: 南亞科期貨近月
# 類別: CYF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2408
# 單位: 1
# 漲停價: 46.8
# 跌停價: 38.3
# 參考價: 42.55
# 更新日期: 2025/03/20
# 目標代碼: CYFD5
# --------------------------------------------------
# 商品代碼: CZFR1
# 符號: CZFR1
# 名稱: 長榮期貨近月
# 類別: CZF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2603
# 單位: 1
# 漲停價: 250.5
# 跌停價: 205.5
# 參考價: 228.0
# 更新日期: 2025/03/20
# 目標代碼: CZFD5
# --------------------------------------------------
# 商品代碼: DAFR1
# 符號: DAFR1
# 名稱: 陽明期貨近月
# 類別: DAF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2609
# 單位: 1
# 漲停價: 85.0
# 跌停價: 69.6
# 參考價: 77.3
# 更新日期: 2025/03/20
# 目標代碼: DAFD5
# --------------------------------------------------
# 商品代碼: DBFR1
# 符號: DBFR1
# 名稱: 華航期貨近月
# 類別: DBF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2610
# 單位: 1
# 漲停價: 26.4
# 跌停價: 21.6
# 參考價: 24.0
# 更新日期: 2025/03/20
# 目標代碼: DBFD5
# --------------------------------------------------
# 商品代碼: DCFR1
# 符號: DCFR1
# 名稱: 彰銀期貨近月
# 類別: DCF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2801
# 單位: 1
# 漲停價: 19.65
# 跌停價: 16.15
# 參考價: 17.9
# 更新日期: 2025/03/20
# 目標代碼: DCFD5
# --------------------------------------------------
# 商品代碼: DDFR1
# 符號: DDFR1
# 名稱: 新光金期貨近月
# 類別: DDF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2888
# 單位: 1
# 漲停價: 13.9
# 跌停價: 11.4
# 參考價: 12.65
# 更新日期: 2025/03/20
# 目標代碼: DDFD5
# --------------------------------------------------
# 商品代碼: DE1R1
# 符號: DE1R1
# 名稱: 永豐金期貨近月
# 類別: DE1
# 交割月份: 202506
# 交割日期: 2025/06/18
# 標的種類: S
# 標的代碼: 2890
# 單位: 1
# 漲停價: 24.2
# 跌停價: 19.8
# 參考價: 22.0
# 更新日期: 2025/03/20
# 目標代碼: DE1F5
# --------------------------------------------------
# 商品代碼: DEFR1
# 符號: DEFR1
# 名稱: 永豐金期貨近月
# 類別: DEF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2890
# 單位: 1
# 漲停價: 24.5
# 跌停價: 20.1
# 參考價: 22.3
# 更新日期: 2025/03/20
# 目標代碼: DEFD5
# --------------------------------------------------
# 商品代碼: DFFR1
# 符號: DFFR1
# 名稱: 台泥期貨近月
# 類別: DFF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 1101
# 單位: 1
# 漲停價: 37.25
# 跌停價: 30.55
# 參考價: 33.9
# 更新日期: 2025/03/20
# 目標代碼: DFFD5
# --------------------------------------------------
# 商品代碼: DGFR1
# 符號: DGFR1
# 名稱: 台化期貨近月
# 類別: DGF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 1326
# 單位: 1
# 漲停價: 31.95
# 跌停價: 26.15
# 參考價: 29.05
# 更新日期: 2025/03/20
# 目標代碼: DGFD5
# --------------------------------------------------
# 商品代碼: DHFR1
# 符號: DHFR1
# 名稱: 鴻海期貨近月
# 類別: DHF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2317
# 單位: 1
# 漲停價: 181.5
# 跌停價: 148.5
# 參考價: 165.0
# 更新日期: 2025/03/20
# 目標代碼: DHFD5
# --------------------------------------------------
# 商品代碼: DIFR1
# 符號: DIFR1
# 名稱: 旺宏期貨近月
# 類別: DIF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2337
# 單位: 1
# 漲停價: 23.9
# 跌停價: 19.6
# 參考價: 21.75
# 更新日期: 2025/03/20
# 目標代碼: DIFD5
# --------------------------------------------------
# 商品代碼: DJFR1
# 符號: DJFR1
# 名稱: 華碩期貨近月
# 類別: DJF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2357
# 單位: 1
# 漲停價: 710.0
# 跌停價: 582.0
# 參考價: 646.0
# 更新日期: 2025/03/20
# 目標代碼: DJFD5
# --------------------------------------------------
# 商品代碼: DKFR1
# 符號: DKFR1
# 名稱: 廣達期貨近月
# 類別: DKF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2382
# 單位: 1
# 漲停價: 279.0
# 跌停價: 229.0
# 參考價: 254.0
# 更新日期: 2025/03/20
# 目標代碼: DKFD5
# --------------------------------------------------
# 商品代碼: DLFR1
# 符號: DLFR1
# 名稱: 中華電期貨近月
# 類別: DLF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2412
# 單位: 1
# 漲停價: 141.0
# 跌停價: 116.0
# 參考價: 128.5
# 更新日期: 2025/03/20
# 目標代碼: DLFD5
# --------------------------------------------------
# 商品代碼: DNFR1
# 符號: DNFR1
# 名稱: 玉山金期貨近月
# 類別: DNF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2884
# 單位: 1
# 漲停價: 32.8
# 跌停價: 26.9
# 參考價: 29.85
# 更新日期: 2025/03/20
# 目標代碼: DNFD5
# --------------------------------------------------
# 商品代碼: DOFR1
# 符號: DOFR1
# 名稱: 元大金期貨近月
# 類別: DOF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2885
# 單位: 1
# 漲停價: 38.8
# 跌停價: 31.8
# 參考價: 35.3
# 更新日期: 2025/03/20
# 目標代碼: DOFD5
# --------------------------------------------------
# 商品代碼: DPFR1
# 符號: DPFR1
# 名稱: 第一金期貨近月
# 類別: DPF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2892
# 單位: 1
# 漲停價: 30.55
# 跌停價: 25.05
# 參考價: 27.8
# 更新日期: 2025/03/20
# 目標代碼: DPFD5
# --------------------------------------------------
# 商品代碼: DQ1R1
# 符號: DQ1R1
# 名稱: 群創期貨近月
# 類別: DQ1
# 交割月份: 202506
# 交割日期: 2025/06/18
# 標的種類: S
# 標的代碼: 3481
# 單位: 1
# 漲停價: 18.0
# 跌停價: 14.8
# 參考價: 16.4
# 更新日期: 2025/03/20
# 目標代碼: DQ1F5
# --------------------------------------------------
# 商品代碼: DQFR1
# 符號: DQFR1
# 名稱: 群創期貨近月
# 類別: DQF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 3481
# 單位: 1
# 漲停價: 17.95
# 跌停價: 14.75
# 參考價: 16.35
# 更新日期: 2025/03/20
# 目標代碼: DQFD5
# --------------------------------------------------
# 商品代碼: DSFR1
# 符號: DSFR1
# 名稱: 宏碁期貨近月
# 類別: DSF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2353
# 單位: 1
# 漲停價: 42.4
# 跌停價: 34.7
# 參考價: 38.55
# 更新日期: 2025/03/20
# 目標代碼: DSFD5
# --------------------------------------------------
# 商品代碼: DVFR1
# 符號: DVFR1
# 名稱: 聯發科期貨近月
# 類別: DVF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2454
# 單位: 1
# 漲停價: 1625.0
# 跌停價: 1335.0
# 參考價: 1480.0
# 更新日期: 2025/03/20
# 目標代碼: DVFD5
# --------------------------------------------------
# 商品代碼: DWFR1
# 符號: DWFR1
# 名稱: 潤泰全期貨近月
# 類別: DWF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2915
# 單位: 1
# 漲停價: 69.9
# 跌停價: 57.3
# 參考價: 63.6
# 更新日期: 2025/03/20
# 目標代碼: DWFD5
# --------------------------------------------------
# 商品代碼: DXFR1
# 符號: DXFR1
# 名稱: 緯創期貨近月
# 類別: DXF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 3231
# 單位: 1
# 漲停價: 114.0
# 跌停價: 93.6
# 參考價: 104.0
# 更新日期: 2025/03/20
# 目標代碼: DXFD5
# --------------------------------------------------
# 商品代碼: DYFR1
# 符號: DYFR1
# 名稱: 亞泥期貨近月
# 類別: DYF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 1102
# 單位: 1
# 漲停價: 49.35
# 跌停價: 40.45
# 參考價: 44.9
# 更新日期: 2025/03/20
# 目標代碼: DYFD5
# --------------------------------------------------
# 商品代碼: DZFR1
# 符號: DZFR1
# 名稱: 大成期貨近月
# 類別: DZF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 1210
# 單位: 1
# 漲停價: 63.4
# 跌停價: 52.0
# 參考價: 57.7
# 更新日期: 2025/03/20
# 目標代碼: DZFD5
# --------------------------------------------------
# 商品代碼: E4FR1
# 符號: E4FR1
# 名稱: 臺灣永續期貨近月
# 類別: E4F
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: I
# 標的代碼:
# 單位: 1
# 漲停價: 12778.0
# 跌停價: 10456.0
# 參考價: 11617.0
# 更新日期: 2025/03/20
# 目標代碼: E4FD5
# --------------------------------------------------
# 商品代碼: ECFR1
# 符號: ECFR1
# 名稱: 歐元近月
# 類別: ECF
# 交割月份: 202503
# 交割日期: 2025/03/20
# 標的種類: E
# 標的代碼:
# 單位: 1
# 漲停價: 0.0
# 跌停價: 0.0
# 參考價: 1.0962
# 更新日期: 2025/03/20
# 目標代碼: ECF5
# --------------------------------------------------
# 商品代碼: ECIR1
# 符號: ECIR1
# 名稱: 歐元近月
# 類別: ECI
# 交割月份: 202503
# 交割日期: 2025/03/20
# 標的種類: E
# 標的代碼:
# 單位: 1
# 漲停價: 0.0
# 跌停價: 0.0
# 參考價: 1.1018
# 更新日期: 2025/03/20
# 目標代碼: ECI5
# --------------------------------------------------
# 商品代碼: ECLR1
# 符號: ECLR1
# 名稱: 歐元近月
# 類別: ECL
# 交割月份: 202503
# 交割日期: 2025/03/20
# 標的種類: E
# 標的代碼:
# 單位: 1
# 漲停價: 0.0
# 跌停價: 0.0
# 參考價: 1.1073
# 更新日期: 2025/03/20
# 目標代碼: ECL5
# --------------------------------------------------
# 商品代碼: EEFR1
# 符號: EEFR1
# 名稱: 國喬期貨近月
# 類別: EEF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 1312
# 單位: 1
# 漲停價: 12.45
# 跌停價: 10.25
# 參考價: 11.35
# 更新日期: 2025/03/20
# 目標代碼: EEFD5
# --------------------------------------------------
# 商品代碼: EGFR1
# 符號: EGFR1
# 名稱: 中石化期貨近月
# 類別: EGF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 1314
# 單位: 1
# 漲停價: 8.66
# 跌停價: 7.1
# 參考價: 7.88
# 更新日期: 2025/03/20
# 目標代碼: EGFD5
# --------------------------------------------------
# 商品代碼: EHFR1
# 符號: EHFR1
# 名稱: 東陽期貨近月
# 類別: EHF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 1319
# 單位: 1
# 漲停價: 146.5
# 跌停價: 120.5
# 參考價: 133.5
# 更新日期: 2025/03/20
# 目標代碼: EHFD5
# --------------------------------------------------
# 商品代碼: EKFR1
# 符號: EKFR1
# 名稱: 南紡期貨近月
# 類別: EKF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 1440
# 單位: 1
# 漲停價: 15.8
# 跌停價: 13.0
# 參考價: 14.4
# 更新日期: 2025/03/20
# 目標代碼: EKFD5
# --------------------------------------------------
# 商品代碼: EMFR1
# 符號: EMFR1
# 名稱: 東元期貨近月
# 類別: EMF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 1504
# 單位: 1
# 漲停價: 57.6
# 跌停價: 47.2
# 參考價: 52.4
# 更新日期: 2025/03/20
# 目標代碼: EMFD5
# --------------------------------------------------
# 商品代碼: EPFR1
# 符號: EPFR1
# 名稱: 亞德客-KY期貨近月
# 類別: EPF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 1590
# 單位: 1
# 漲停價: 1080.0
# 跌停價: 886.0
# 參考價: 984.0
# 更新日期: 2025/03/20
# 目標代碼: EPFD5
# --------------------------------------------------
# 商品代碼: ESCR1
# 符號: ESCR1
# 名稱: 小SP近月
# 類別: ESC
# 交割月份: 202503
# 交割日期: 2025/03/20
# 標的種類: E
# 標的代碼:
# 單位: 1
# 漲停價: 0.0
# 跌停價: 0.0
# 參考價: 5678.5
# 更新日期: 2025/03/20
# 目標代碼: ESC5
# --------------------------------------------------
# 商品代碼: ESFR1
# 符號: ESFR1
# 名稱: 小SP近月
# 類別: ESF
# 交割月份: 202503
# 交割日期: 2025/03/20
# 標的種類: E
# 標的代碼:
# 單位: 1
# 漲停價: 0.0
# 跌停價: 0.0
# 參考價: 5729.75
# 更新日期: 2025/03/20
# 目標代碼: ESF5
# --------------------------------------------------
# 商品代碼: ESIR1
# 符號: ESIR1
# 名稱: 小SP近月
# 類別: ESI
# 交割月份: 202503
# 交割日期: 2025/03/20
# 標的種類: E
# 標的代碼:
# 單位: 1
# 漲停價: 0.0
# 跌停價: 0.0
# 參考價: 5779.5
# 更新日期: 2025/03/20
# 目標代碼: ESI5
# --------------------------------------------------
# 商品代碼: ESLR1
# 符號: ESLR1
# 名稱: 小SP近月
# 類別: ESL
# 交割月份: 202503
# 交割日期: 2025/03/20
# 標的種類: E
# 標的代碼:
# 單位: 1
# 漲停價: 0.0
# 跌停價: 0.0
# 參考價: 5825.75
# 更新日期: 2025/03/20
# 目標代碼: ESL5
# --------------------------------------------------
# 商品代碼: EXFR1
# 符號: EXFR1
# 名稱: 電子期貨近月
# 類別: EXF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: I
# 標的代碼:
# 單位: 1
# 漲停價: 1301.55
# 跌停價: 1064.95
# 參考價: 1183.25
# 更新日期: 2025/03/20
# 目標代碼: EXFD5
# --------------------------------------------------
# 商品代碼: EYFR1
# 符號: EYFR1
# 名稱: 中纖期貨近月
# 類別: EYF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 1718
# 單位: 1
# 漲停價: 8.05
# 跌停價: 6.59
# 參考價: 7.32
# 更新日期: 2025/03/20
# 目標代碼: EYFD5
# --------------------------------------------------
# 商品代碼: EZFR1
# 符號: EZFR1
# 名稱: 台肥期貨近月
# 類別: EZF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 1722
# 單位: 1
# 漲停價: 58.1
# 跌停價: 47.65
# 參考價: 52.9
# 更新日期: 2025/03/20
# 目標代碼: EZFD5
# --------------------------------------------------
# 商品代碼: F1FR1
# 符號: F1FR1
# 名稱: 英國富時100期貨近月
# 類別: F1F
# 交割月份: 202503
# 交割日期: 2025/03/24
# 標的種類: I
# 標的代碼:
# 單位: 1
# 漲停價: 9312.0
# 跌停價: 8094.0
# 參考價: 8703.0
# 更新日期: 2025/03/20
# 目標代碼: F1FC5
# --------------------------------------------------
# 商品代碼: FBFR1
# 符號: FBFR1
# 名稱: 東和鋼鐵期貨近月
# 類別: FBF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2006
# 單位: 1
# 漲停價: 78.9
# 跌停價: 64.7
# 參考價: 71.8
# 更新日期: 2025/03/20
# 目標代碼: FBFD5
# --------------------------------------------------
# 商品代碼: FCFR1
# 符號: FCFR1
# 名稱: 中鴻期貨近月
# 類別: FCF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2014
# 單位: 1
# 漲停價: 26.95
# 跌停價: 22.05
# 參考價: 24.5
# 更新日期: 2025/03/20
# 目標代碼: FCFD5
# --------------------------------------------------
# 商品代碼: FEFR1
# 符號: FEFR1
# 名稱: 大成鋼期貨近月
# 類別: FEF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2027
# 單位: 1
# 漲停價: 57.8
# 跌停價: 47.35
# 參考價: 52.6
# 更新日期: 2025/03/20
# 目標代碼: FEFD5
# --------------------------------------------------
# 商品代碼: FFFR1
# 符號: FFFR1
# 名稱: 上銀期貨近月
# 類別: FFF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2049
# 單位: 1
# 漲停價: 312.5
# 跌停價: 256.5
# 參考價: 284.5
# 更新日期: 2025/03/20
# 目標代碼: FFFD5
# --------------------------------------------------
# 商品代碼: FGFR1
# 符號: FGFR1
# 名稱: 川湖期貨近月
# 類別: FGF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2059
# 單位: 1
# 漲停價: 2120.0
# 跌停價: 1740.0
# 參考價: 1930.0
# 更新日期: 2025/03/20
# 目標代碼: FGFD5
# --------------------------------------------------
# 商品代碼: FKFR1
# 符號: FKFR1
# 名稱: 正新期貨近月
# 類別: FKF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2105
# 單位: 1
# 漲停價: 56.1
# 跌停價: 45.9
# 參考價: 51.0
# 更新日期: 2025/03/20
# 目標代碼: FKFD5
# --------------------------------------------------
# 商品代碼: FNFR1
# 符號: FNFR1
# 名稱: 裕隆期貨近月
# 類別: FNF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2201
# 單位: 1
# 漲停價: 51.2
# 跌停價: 41.9
# 參考價: 46.55
# 更新日期: 2025/03/20
# 目標代碼: FNFD5
# --------------------------------------------------
# 商品代碼: FQFR1
# 符號: FQFR1
# 名稱: 光寶科期貨近月
# 類別: FQF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2301
# 單位: 1
# 漲停價: 113.5
# 跌停價: 93.2
# 參考價: 103.5
# 更新日期: 2025/03/20
# 目標代碼: FQFD5
# --------------------------------------------------
# 商品代碼: FRFR1
# 符號: FRFR1
# 名稱: 台達電期貨近月
# 類別: FRF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2308
# 單位: 1
# 漲停價: 432.5
# 跌停價: 354.5
# 參考價: 393.5
# 更新日期: 2025/03/20
# 目標代碼: FRFD5
# --------------------------------------------------
# 商品代碼: FSFR1
# 符號: FSFR1
# 名稱: 金寶期貨近月
# 類別: FSF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2312
# 單位: 1
# 漲停價: 25.5
# 跌停價: 20.9
# 參考價: 23.2
# 更新日期: 2025/03/20
# 目標代碼: FSFD5
# --------------------------------------------------
# 商品代碼: FTFR1
# 符號: FTFR1
# 名稱: 華通期貨近月
# 類別: FTF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2313
# 單位: 1
# 漲停價: 70.9
# 跌停價: 58.1
# 參考價: 64.5
# 更新日期: 2025/03/20
# 目標代碼: FTFD5
# --------------------------------------------------
# 商品代碼: FVFR1
# 符號: FVFR1
# 名稱: 精英期貨近月
# 類別: FVF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2331
# 單位: 1
# 漲停價: 22.05
# 跌停價: 18.05
# 參考價: 20.05
# 更新日期: 2025/03/20
# 目標代碼: FVFD5
# --------------------------------------------------
# 商品代碼: FWFR1
# 符號: FWFR1
# 名稱: 友訊期貨近月
# 類別: FWF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2332
# 單位: 1
# 漲停價: 23.3
# 跌停價: 19.1
# 參考價: 21.2
# 更新日期: 2025/03/20
# 目標代碼: FWFD5
# --------------------------------------------------
# 商品代碼: FXFR1
# 符號: FXFR1
# 名稱: 金融期貨近月
# 類別: FXF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: I
# 標的代碼:
# 單位: 1
# 漲停價: 2360.2
# 跌停價: 1931.4
# 參考價: 2145.8
# 更新日期: 2025/03/20
# 目標代碼: FXFD5
# --------------------------------------------------
# 商品代碼: FYFR1
# 符號: FYFR1
# 名稱: 台亞期貨近月
# 類別: FYF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2340
# 單位: 1
# 漲停價: 27.95
# 跌停價: 22.95
# 參考價: 25.45
# 更新日期: 2025/03/20
# 目標代碼: FYFD5
# --------------------------------------------------
# 商品代碼: FZFR1
# 符號: FZFR1
# 名稱: 華邦電期貨近月
# 類別: FZF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2344
# 單位: 1
# 漲停價: 22.7
# 跌停價: 18.6
# 參考價: 20.65
# 更新日期: 2025/03/20
# 目標代碼: FZFD5
# --------------------------------------------------
# 商品代碼: G2FR1
# 符號: G2FR1
# 名稱: 富櫃200期貨近月
# 類別: G2F
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: I
# 標的代碼:
# 單位: 1
# 漲停價: 10687.0
# 跌停價: 8745.0
# 參考價: 9716.0
# 更新日期: 2025/03/20
# 目標代碼: G2FD5
# --------------------------------------------------
# 商品代碼: GAFR1
# 符號: GAFR1
# 名稱: 聯強期貨近月
# 類別: GAF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2347
# 單位: 1
# 漲停價: 81.1
# 跌停價: 66.5
# 參考價: 73.8
# 更新日期: 2025/03/20
# 目標代碼: GAFD5
# --------------------------------------------------
# 商品代碼: GCFR1
# 符號: GCFR1
# 名稱: 鴻準期貨近月
# 類別: GCF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2354
# 單位: 1
# 漲停價: 77.0
# 跌停價: 63.0
# 參考價: 70.0
# 更新日期: 2025/03/20
# 目標代碼: GCFD5
# --------------------------------------------------
# 商品代碼: GDFR1
# 符號: GDFR1
# 名稱: 黃金期貨近月
# 類別: GDF
# 交割月份: 202504
# 交割日期: 2025/04/29
# 標的種類: C
# 標的代碼:
# 單位: 1
# 漲停價: 3202.1
# 跌停價: 2897.3
# 參考價: 3049.7
# 更新日期: 2025/03/20
# 目標代碼: GDFD5
# --------------------------------------------------
# 商品代碼: GHFR1
# 符號: GHFR1
# 名稱: 技嘉期貨近月
# 類別: GHF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2376
# 單位: 1
# 漲停價: 289.0
# 跌停價: 237.0
# 參考價: 263.0
# 更新日期: 2025/03/20
# 目標代碼: GHFD5
# --------------------------------------------------
# 商品代碼: GIFR1
# 符號: GIFR1
# 名稱: 微星期貨近月
# 類別: GIF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2377
# 單位: 1
# 漲停價: 189.0
# 跌停價: 155.0
# 參考價: 172.0
# 更新日期: 2025/03/20
# 目標代碼: GIFD5
# --------------------------------------------------
# 商品代碼: GJFR1
# 符號: GJFR1
# 名稱: 瑞昱期貨近月
# 類別: GJF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2379
# 單位: 1
# 漲停價: 595.0
# 跌停價: 487.0
# 參考價: 541.0
# 更新日期: 2025/03/20
# 目標代碼: GJFD5
# --------------------------------------------------
# 商品代碼: GKFR1
# 符號: GKFR1
# 名稱: 群光期貨近月
# 類別: GKF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2385
# 單位: 1
# 漲停價: 189.0
# 跌停價: 155.0
# 參考價: 172.0
# 更新日期: 2025/03/20
# 目標代碼: GKFD5
# --------------------------------------------------
# 商品代碼: GLFR1
# 符號: GLFR1
# 名稱: 正崴期貨近月
# 類別: GLF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2392
# 單位: 1
# 漲停價: 67.8
# 跌停價: 55.6
# 參考價: 61.7
# 更新日期: 2025/03/20
# 目標代碼: GLFD5
# --------------------------------------------------
# 商品代碼: GMFR1
# 符號: GMFR1
# 名稱: 億光期貨近月
# 類別: GMF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2393
# 單位: 1
# 漲停價: 91.9
# 跌停價: 75.3
# 參考價: 83.6
# 更新日期: 2025/03/20
# 目標代碼: GMFD5
# --------------------------------------------------
# 商品代碼: GNFR1
# 符號: GNFR1
# 名稱: 凌陽期貨近月
# 類別: GNF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2401
# 單位: 1
# 漲停價: 31.05
# 跌停價: 25.45
# 參考價: 28.25
# 更新日期: 2025/03/20
# 目標代碼: GNFD5
# --------------------------------------------------
# 商品代碼: GOFR1
# 符號: GOFR1
# 名稱: 漢唐期貨近月
# 類別: GOF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2404
# 單位: 1
# 漲停價: 471.5
# 跌停價: 386.5
# 參考價: 429.0
# 更新日期: 2025/03/20
# 目標代碼: GOFD5
# --------------------------------------------------
# 商品代碼: GRFR1
# 符號: GRFR1
# 名稱: 京元電子期貨近月
# 類別: GRF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2449
# 單位: 1
# 漲停價: 108.5
# 跌停價: 89.0
# 參考價: 98.8
# 更新日期: 2025/03/20
# 目標代碼: GRFD5
# --------------------------------------------------
# 商品代碼: GTFR1
# 符號: GTFR1
# 名稱: 櫃買期貨近月
# 類別: GTF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: I
# 標的代碼:
# 單位: 1
# 漲停價: 275.2
# 跌停價: 225.2
# 參考價: 250.2
# 更新日期: 2025/03/20
# 目標代碼: GTFD5
# --------------------------------------------------
# 商品代碼: GUFR1
# 符號: GUFR1
# 名稱: 全新期貨近月
# 類別: GUF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2455
# 單位: 1
# 漲停價: 143.5
# 跌停價: 117.5
# 參考價: 130.5
# 更新日期: 2025/03/20
# 目標代碼: GUFD5
# --------------------------------------------------
# 商品代碼: GVFR1
# 符號: GVFR1
# 名稱: 飛宏期貨近月
# 類別: GVF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2457
# 單位: 1
# 漲停價: 35.0
# 跌停價: 28.7
# 參考價: 31.85
# 更新日期: 2025/03/20
# 目標代碼: GVFD5
# --------------------------------------------------
# 商品代碼: GWFR1
# 符號: GWFR1
# 名稱: 義隆期貨近月
# 類別: GWF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2458
# 單位: 1
# 漲停價: 169.5
# 跌停價: 139.5
# 參考價: 154.5
# 更新日期: 2025/03/20
# 目標代碼: GWFD5
# --------------------------------------------------
# 商品代碼: GXFR1
# 符號: GXFR1
# 名稱: 可成期貨近月
# 類別: GXF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2474
# 單位: 1
# 漲停價: 230.0
# 跌停價: 189.0
# 參考價: 209.5
# 更新日期: 2025/03/20
# 目標代碼: GXFD5
# --------------------------------------------------
# 商品代碼: GYFR1
# 符號: GYFR1
# 名稱: 強茂期貨近月
# 類別: GYF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2481
# 單位: 1
# 漲停價: 57.4
# 跌停價: 47.0
# 參考價: 52.2
# 更新日期: 2025/03/20
# 目標代碼: GYFD5
# --------------------------------------------------
# 商品代碼: GZFR1
# 符號: GZFR1
# 名稱: 兆赫期貨近月
# 類別: GZF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2485
# 單位: 1
# 漲停價: 15.25
# 跌停價: 12.55
# 參考價: 13.9
# 更新日期: 2025/03/20
# 目標代碼: GZFD5
# --------------------------------------------------
# 商品代碼: HA1R1
# 符號: HA1R1
# 名稱: 瑞軒期貨近月
# 類別: HA1
# 交割月份: 202506
# 交割日期: 2025/06/18
# 標的種類: S
# 標的代碼: 2489
# 單位: 1
# 漲停價: 19.25
# 跌停價: 15.75
# 參考價: 17.5
# 更新日期: 2025/03/20
# 目標代碼: HA1F5
# --------------------------------------------------
# 商品代碼: HAFR1
# 符號: HAFR1
# 名稱: 瑞軒期貨近月
# 類別: HAF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2489
# 單位: 1
# 漲停價: 19.25
# 跌停價: 15.75
# 參考價: 17.5
# 更新日期: 2025/03/20
# 目標代碼: HAFD5
# --------------------------------------------------
# 商品代碼: HBFR1
# 符號: HBFR1
# 名稱: 華新科期貨近月
# 類別: HBF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2492
# 單位: 1
# 漲停價: 105.5
# 跌停價: 86.6
# 參考價: 96.2
# 更新日期: 2025/03/20
# 目標代碼: HBFD5
# --------------------------------------------------
# 商品代碼: HCFR1
# 符號: HCFR1
# 名稱: 宏達電期貨近月
# 類別: HCF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2498
# 單位: 1
# 漲停價: 49.85
# 跌停價: 40.85
# 參考價: 45.35
# 更新日期: 2025/03/20
# 目標代碼: HCFD5
# --------------------------------------------------
# 商品代碼: HHFR1
# 符號: HHFR1
# 名稱: 中工期貨近月
# 類別: HHF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2515
# 單位: 1
# 漲停價: 12.3
# 跌停價: 10.1
# 參考價: 11.2
# 更新日期: 2025/03/20
# 目標代碼: HHFD5
# --------------------------------------------------
# 商品代碼: HIFR1
# 符號: HIFR1
# 名稱: 冠德期貨近月
# 類別: HIF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2520
# 單位: 1
# 漲停價: 61.6
# 跌停價: 50.4
# 參考價: 56.0
# 更新日期: 2025/03/20
# 目標代碼: HIFD5
# --------------------------------------------------
# 商品代碼: HL1R1
# 符號: HL1R1
# 名稱: 興富發期貨近月
# 類別: HL1
# 交割月份: 202506
# 交割日期: 2025/06/18
# 標的種類: S
# 標的代碼: 2542
# 單位: 1
# 漲停價: 47.9
# 跌停價: 39.2
# 參考價: 43.55
# 更新日期: 2025/03/20
# 目標代碼: HL1F5
# --------------------------------------------------
# 商品代碼: HLFR1
# 符號: HLFR1
# 名稱: 興富發期貨近月
# 類別: HLF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2542
# 單位: 1
# 漲停價: 47.55
# 跌停價: 38.95
# 參考價: 43.25
# 更新日期: 2025/03/20
# 目標代碼: HLFD5
# --------------------------------------------------
# 商品代碼: HOFR1
# 符號: HOFR1
# 名稱: 華固期貨近月
# 類別: HOF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2548
# 單位: 1
# 漲停價: 125.0
# 跌停價: 103.0
# 參考價: 114.0
# 更新日期: 2025/03/20
# 目標代碼: HOFD5
# --------------------------------------------------
# 商品代碼: HQFR1
# 符號: HQFR1
# 名稱: 新興期貨近月
# 類別: HQF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2605
# 單位: 1
# 漲停價: 30.35
# 跌停價: 24.85
# 參考價: 27.6
# 更新日期: 2025/03/20
# 目標代碼: HQFD5
# --------------------------------------------------
# 商品代碼: HSFR1
# 符號: HSFR1
# 名稱: 長榮航期貨近月
# 類別: HSF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2618
# 單位: 1
# 漲停價: 47.05
# 跌停價: 38.55
# 參考價: 42.8
# 更新日期: 2025/03/20
# 目標代碼: HSFD5
# --------------------------------------------------
# 商品代碼: IAFR1
# 符號: IAFR1
# 名稱: 臺企銀期貨近月
# 類別: IAF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2834
# 單位: 1
# 漲停價: 16.95
# 跌停價: 13.95
# 參考價: 15.45
# 更新日期: 2025/03/20
# 目標代碼: IAFD5
# --------------------------------------------------
# 商品代碼: IHFR1
# 符號: IHFR1
# 名稱: 農林期貨近月
# 類別: IHF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2913
# 單位: 1
# 漲停價: 21.05
# 跌停價: 17.25
# 參考價: 19.15
# 更新日期: 2025/03/20
# 目標代碼: IHFD5
# --------------------------------------------------
# 商品代碼: IIFR1
# 符號: IIFR1
# 名稱: 晶豪科期貨近月
# 類別: IIF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 3006
# 單位: 1
# 漲停價: 73.1
# 跌停價: 59.9
# 參考價: 66.5
# 更新日期: 2025/03/20
# 目標代碼: IIFD5
# --------------------------------------------------
# 商品代碼: IJFR1
# 符號: IJFR1
# 名稱: 大立光期貨近月
# 類別: IJF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 3008
# 單位: 1
# 漲停價: 2725.0
# 跌停價: 2235.0
# 參考價: 2480.0
# 更新日期: 2025/03/20
# 目標代碼: IJFD5
# --------------------------------------------------
# 商品代碼: IMFR1
# 符號: IMFR1
# 名稱: 亞光期貨近月
# 類別: IMF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 3019
# 單位: 1
# 漲停價: 166.0
# 跌停價: 136.0
# 參考價: 151.0
# 更新日期: 2025/03/20
# 目標代碼: IMFD5
# --------------------------------------------------
# 商品代碼: IOFR1
# 符號: IOFR1
# 名稱: 聯詠期貨近月
# 類別: IOF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 3034
# 單位: 1
# 漲停價: 594.0
# 跌停價: 486.0
# 參考價: 540.0
# 更新日期: 2025/03/20
# 目標代碼: IOFD5
# --------------------------------------------------
# 商品代碼: IPFR1
# 符號: IPFR1
# 名稱: 智原期貨近月
# 類別: IPF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 3035
# 單位: 1
# 漲停價: 249.0
# 跌停價: 204.0
# 參考價: 226.5
# 更新日期: 2025/03/20
# 目標代碼: IPFD5
# --------------------------------------------------
# 商品代碼: IQFR1
# 符號: IQFR1
# 名稱: 文曄期貨近月
# 類別: IQF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 3036
# 單位: 1
# 漲停價: 117.0
# 跌停價: 95.9
# 參考價: 106.5
# 更新日期: 2025/03/20
# 目標代碼: IQFD5
# --------------------------------------------------
# 商品代碼: IRFR1
# 符號: IRFR1
# 名稱: 欣興期貨近月
# 類別: IRF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 3037
# 單位: 1
# 漲停價: 115.5
# 跌停價: 94.5
# 參考價: 105.0
# 更新日期: 2025/03/20
# 目標代碼: IRFD5
# --------------------------------------------------
# 商品代碼: ITFR1
# 符號: ITFR1
# 名稱: 晶技期貨近月
# 類別: ITF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 3042
# 單位: 1
# 漲停價: 108.5
# 跌停價: 89.1
# 參考價: 98.9
# 更新日期: 2025/03/20
# 目標代碼: ITFD5
# --------------------------------------------------
# 商品代碼: IXFR1
# 符號: IXFR1
# 名稱: 景碩期貨近月
# 類別: IXF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 3189
# 單位: 1
# 漲停價: 105.0
# 跌停價: 86.1
# 參考價: 95.6
# 更新日期: 2025/03/20
# 目標代碼: IXFD5
# --------------------------------------------------
# 商品代碼: IYFR1
# 符號: IYFR1
# 名稱: 新日興期貨近月
# 類別: IYF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 3376
# 單位: 1
# 漲停價: 277.0
# 跌停價: 227.0
# 參考價: 252.0
# 更新日期: 2025/03/20
# 目標代碼: IYFD5
# --------------------------------------------------
# 商品代碼: IZFR1
# 符號: IZFR1
# 名稱: 明泰期貨近月
# 類別: IZF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 3380
# 單位: 1
# 漲停價: 35.45
# 跌停價: 29.05
# 參考價: 32.25
# 更新日期: 2025/03/20
# 目標代碼: IZFD5
# --------------------------------------------------
# 商品代碼: JBFR1
# 符號: JBFR1
# 名稱: 創意期貨近月
# 類別: JBF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 3443
# 單位: 1
# 漲停價: 1280.0
# 跌停價: 1050.0
# 參考價: 1165.0
# 更新日期: 2025/03/20
# 目標代碼: JBFD5
# --------------------------------------------------
# 商品代碼: JFFR1
# 符號: JFFR1
# 名稱: 嘉澤期貨近月
# 類別: JFF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 3533
# 單位: 1
# 漲停價: 1710.0
# 跌停價: 1400.0
# 參考價: 1555.0
# 更新日期: 2025/03/20
# 目標代碼: JFFD5
# --------------------------------------------------
# 商品代碼: JMFR1
# 符號: JMFR1
# 名稱: 健策期貨近月
# 類別: JMF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 3653
# 單位: 1
# 漲停價: 1240.0
# 跌停價: 1020.0
# 參考價: 1130.0
# 更新日期: 2025/03/20
# 目標代碼: JMFD5
# --------------------------------------------------
# 商品代碼: JNFR1
# 符號: JNFR1
# 名稱: TPK-KY期貨近月
# 類別: JNF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 3673
# 單位: 1
# 漲停價: 40.4
# 跌停價: 33.1
# 參考價: 36.75
# 更新日期: 2025/03/20
# 目標代碼: JNFD5
# --------------------------------------------------
# 商品代碼: JPFR1
# 符號: JPFR1
# 名稱: 大聯大期貨近月
# 類別: JPF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 3702
# 單位: 1
# 漲停價: 71.8
# 跌停價: 58.8
# 參考價: 65.3
# 更新日期: 2025/03/20
# 目標代碼: JPFD5
# --------------------------------------------------
# 商品代碼: JSFR1
# 符號: JSFR1
# 名稱: 和碩期貨近月
# 類別: JSF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 4938
# 單位: 1
# 漲停價: 100.0
# 跌停價: 82.2
# 參考價: 91.3
# 更新日期: 2025/03/20
# 目標代碼: JSFD5
# --------------------------------------------------
# 商品代碼: JWFR1
# 符號: JWFR1
# 名稱: 長虹期貨近月
# 類別: JWF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 5534
# 單位: 1
# 漲停價: 107.0
# 跌停價: 87.6
# 參考價: 97.3
# 更新日期: 2025/03/20
# 目標代碼: JWFD5
# --------------------------------------------------
# 商品代碼: JXFR1
# 符號: JXFR1
# 名稱: 群益證期貨近月
# 類別: JXF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 6005
# 單位: 1
# 漲停價: 29.35
# 跌停價: 24.05
# 參考價: 26.7
# 更新日期: 2025/03/20
# 目標代碼: JXFD5
# --------------------------------------------------
# 商品代碼: JZ1R1
# 符號: JZ1R1
# 名稱: 嘉聯益期貨近月
# 類別: JZ1
# 交割月份: 202506
# 交割日期: 2025/06/18
# 標的種類: S
# 標的代碼: 6153
# 單位: 1
# 漲停價: 16.05
# 跌停價: 13.15
# 參考價: 14.6
# 更新日期: 2025/03/20
# 目標代碼: JZ1F5
# --------------------------------------------------
# 商品代碼: JZFR1
# 符號: JZFR1
# 名稱: 嘉聯益期貨近月
# 類別: JZF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 6153
# 單位: 1
# 漲停價: 16.2
# 跌停價: 13.3
# 參考價: 14.75
# 更新日期: 2025/03/20
# 目標代碼: JZFD5
# --------------------------------------------------
# 商品代碼: KAFR1
# 符號: KAFR1
# 名稱: 瑞儀期貨近月
# 類別: KAF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 6176
# 單位: 1
# 漲停價: 199.5
# 跌停價: 163.5
# 參考價: 181.5
# 更新日期: 2025/03/20
# 目標代碼: KAFD5
# --------------------------------------------------
# 商品代碼: KBFR1
# 符號: KBFR1
# 名稱: 聯茂期貨近月
# 類別: KBF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 6213
# 單位: 1
# 漲停價: 78.5
# 跌停價: 64.3
# 參考價: 71.4
# 更新日期: 2025/03/20
# 目標代碼: KBFD5
# --------------------------------------------------
# 商品代碼: KCFR1
# 符號: KCFR1
# 名稱: 力成期貨近月
# 類別: KCF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 6239
# 單位: 1
# 漲停價: 143.0
# 跌停價: 117.0
# 參考價: 130.0
# 更新日期: 2025/03/20
# 目標代碼: KCFD5
# --------------------------------------------------
# 商品代碼: KDFR1
# 符號: KDFR1
# 名稱: 同欣電期貨近月
# 類別: KDF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 6271
# 單位: 1
# 漲停價: 127.5
# 跌停價: 104.5
# 參考價: 116.0
# 更新日期: 2025/03/20
# 目標代碼: KDFD5
# --------------------------------------------------
# 商品代碼: KEFR1
# 符號: KEFR1
# 名稱: 台表科期貨近月
# 類別: KEF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 6278
# 單位: 1
# 漲停價: 127.5
# 跌停價: 104.5
# 參考價: 116.0
# 更新日期: 2025/03/20
# 目標代碼: KEFD5
# --------------------------------------------------
# 商品代碼: KFFR1
# 符號: KFFR1
# 名稱: 康舒期貨近月
# 類別: KFF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 6282
# 單位: 1
# 漲停價: 34.5
# 跌停價: 28.3
# 參考價: 31.4
# 更新日期: 2025/03/20
# 目標代碼: KFFD5
# --------------------------------------------------
# 商品代碼: KGFR1
# 符號: KGFR1
# 名稱: 啟碁期貨近月
# 類別: KGF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 6285
# 單位: 1
# 漲停價: 161.5
# 跌停價: 132.5
# 參考價: 147.0
# 更新日期: 2025/03/20
# 目標代碼: KGFD5
# --------------------------------------------------
# 商品代碼: KIFR1
# 符號: KIFR1
# 名稱: 台虹期貨近月
# 類別: KIF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 8039
# 單位: 1
# 漲停價: 53.5
# 跌停價: 43.85
# 參考價: 48.7
# 更新日期: 2025/03/20
# 目標代碼: KIFD5
# --------------------------------------------------
# 商品代碼: KKFR1
# 符號: KKFR1
# 名稱: 達方期貨近月
# 類別: KKF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 8163
# 單位: 1
# 漲停價: 46.1
# 跌停價: 37.8
# 參考價: 41.95
# 更新日期: 2025/03/20
# 目標代碼: KKFD5
# --------------------------------------------------
# 商品代碼: KLFR1
# 符號: KLFR1
# 名稱: 寶成期貨近月
# 類別: KLF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 9904
# 單位: 1
# 漲停價: 39.65
# 跌停價: 32.45
# 參考價: 36.05
# 更新日期: 2025/03/20
# 目標代碼: KLFD5
# --------------------------------------------------
# 商品代碼: KOFR1
# 符號: KOFR1
# 名稱: 宏全期貨近月
# 類別: KOF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 9939
# 單位: 1
# 漲停價: 176.5
# 跌停價: 144.5
# 參考價: 160.5
# 更新日期: 2025/03/20
# 目標代碼: KOFD5
# --------------------------------------------------
# 商品代碼: KPFR1
# 符號: KPFR1
# 名稱: 潤泰新期貨近月
# 類別: KPF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 9945
# 單位: 1
# 漲停價: 41.5
# 跌停價: 34.0
# 參考價: 37.75
# 更新日期: 2025/03/20
# 目標代碼: KPFD5
# --------------------------------------------------
# 商品代碼: KSFR1
# 符號: KSFR1
# 名稱: 聚陽期貨近月
# 類別: KSF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 1477
# 單位: 1
# 漲停價: 367.5
# 跌停價: 301.5
# 參考價: 334.5
# 更新日期: 2025/03/20
# 目標代碼: KSFD5
# --------------------------------------------------
# 商品代碼: KUFR1
# 符號: KUFR1
# 名稱: 台玻期貨近月
# 類別: KUF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 1802
# 單位: 1
# 漲停價: 19.25
# 跌停價: 15.75
# 參考價: 17.5
# 更新日期: 2025/03/20
# 目標代碼: KUFD5
# --------------------------------------------------
# 商品代碼: KWFR1
# 符號: KWFR1
# 名稱: 廣宇期貨近月
# 類別: KWF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2328
# 單位: 1
# 漲停價: 59.4
# 跌停價: 48.6
# 參考價: 54.0
# 更新日期: 2025/03/20
# 目標代碼: KWFD5
# --------------------------------------------------
# 商品代碼: LBFR1
# 符號: LBFR1
# 名稱: 健鼎期貨近月
# 類別: LBF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 3044
# 單位: 1
# 漲停價: 224.5
# 跌停價: 184.5
# 參考價: 204.5
# 更新日期: 2025/03/20
# 目標代碼: LBFD5
# --------------------------------------------------
# 商品代碼: LCFR1
# 符號: LCFR1
# 名稱: 台灣大期貨近月
# 類別: LCF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 3045
# 單位: 1
# 漲停價: 127.5
# 跌停價: 104.5
# 參考價: 116.0
# 更新日期: 2025/03/20
# 目標代碼: LCFD5
# --------------------------------------------------
# 商品代碼: LEFR1
# 符號: LEFR1
# 名稱: 玉晶光期貨近月
# 類別: LEF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 3406
# 單位: 1
# 漲停價: 465.5
# 跌停價: 381.5
# 參考價: 423.5
# 更新日期: 2025/03/20
# 目標代碼: LEFD5
# --------------------------------------------------
# 商品代碼: LIFR1
# 符號: LIFR1
# 名稱: 台郡期貨近月
# 類別: LIF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 6269
# 單位: 1
# 漲停價: 70.0
# 跌停價: 57.4
# 參考價: 63.7
# 更新日期: 2025/03/20
# 目標代碼: LIFD5
# --------------------------------------------------
# 商品代碼: LMFR1
# 符號: LMFR1
# 名稱: 美利達期貨近月
# 類別: LMF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 9914
# 單位: 1
# 漲停價: 191.0
# 跌停價: 157.0
# 參考價: 174.0
# 更新日期: 2025/03/20
# 目標代碼: LMFD5
# --------------------------------------------------
# 商品代碼: LOFR1
# 符號: LOFR1
# 名稱: 合庫金期貨近月
# 類別: LOF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 5880
# 單位: 1
# 漲停價: 26.85
# 跌停價: 22.05
# 參考價: 24.45
# 更新日期: 2025/03/20
# 目標代碼: LOFD5
# --------------------------------------------------
# 商品代碼: LQFR1
# 符號: LQFR1
# 名稱: 英業達期貨近月
# 類別: LQF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2356
# 單位: 1
# 漲停價: 52.0
# 跌停價: 42.65
# 參考價: 47.35
# 更新日期: 2025/03/20
# 目標代碼: LQFD5
# --------------------------------------------------
# 商品代碼: LRFR1
# 符號: LRFR1
# 名稱: 凱基金期貨近月
# 類別: LRF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2883
# 單位: 1
# 漲停價: 20.25
# 跌停價: 16.65
# 參考價: 18.45
# 更新日期: 2025/03/20
# 目標代碼: LRFD5
# --------------------------------------------------
# 商品代碼: LTFR1
# 符號: LTFR1
# 名稱: 遠傳期貨近月
# 類別: LTF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 4904
# 單位: 1
# 漲停價: 100.5
# 跌停價: 82.5
# 參考價: 91.6
# 更新日期: 2025/03/20
# 目標代碼: LTFD5
# --------------------------------------------------
# 商品代碼: LUFR1
# 符號: LUFR1
# 名稱: 臻鼎-KY期貨近月
# 類別: LUF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 4958
# 單位: 1
# 漲停價: 122.5
# 跌停價: 100.5
# 參考價: 111.5
# 更新日期: 2025/03/20
# 目標代碼: LUFD5
# --------------------------------------------------
# 商品代碼: LV1R1
# 符號: LV1R1
# 名稱: 中租-KY期貨近月
# 類別: LV1
# 交割月份: 202506
# 交割日期: 2025/06/18
# 標的種類: S
# 標的代碼: 5871
# 單位: 1
# 漲停價: 135.5
# 跌停價: 111.5
# 參考價: 123.5
# 更新日期: 2025/03/20
# 目標代碼: LV1F5
# --------------------------------------------------
# 商品代碼: LVFR1
# 符號: LVFR1
# 名稱: 中租-KY期貨近月
# 類別: LVF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 5871
# 單位: 1
# 漲停價: 136.0
# 跌停價: 112.0
# 參考價: 124.0
# 更新日期: 2025/03/20
# 目標代碼: LVFD5
# --------------------------------------------------
# 商品代碼: LWFR1
# 符號: LWFR1
# 名稱: 儒鴻期貨近月
# 類別: LWF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 1476
# 單位: 1
# 漲停價: 550.0
# 跌停價: 450.0
# 參考價: 500.0
# 更新日期: 2025/03/20
# 目標代碼: LWFD5
# --------------------------------------------------
# 商品代碼: LXFR1
# 符號: LXFR1
# 名稱: 國巨期貨近月
# 類別: LXF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2327
# 單位: 1
# 漲停價: 583.0
# 跌停價: 477.0
# 參考價: 530.0
# 更新日期: 2025/03/20
# 目標代碼: LXFD5
# --------------------------------------------------
# 商品代碼: LYFR1
# 符號: LYFR1
# 名稱: 南電期貨近月
# 類別: LYF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 8046
# 單位: 1
# 漲停價: 140.0
# 跌停價: 115.0
# 參考價: 127.5
# 更新日期: 2025/03/20
# 目標代碼: LYFD5
# --------------------------------------------------
# 商品代碼: M1FR1
# 符號: M1FR1
# 名稱: 臺灣中型100期貨近月
# 類別: M1F
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: I
# 標的代碼:
# 單位: 1
# 漲停價: 21182.0
# 跌停價: 17332.0
# 參考價: 19257.0
# 更新日期: 2025/03/20
# 目標代碼: M1FD5
# --------------------------------------------------
# 商品代碼: MAFR1
# 符號: MAFR1
# 名稱: 葡萄王期貨近月
# 類別: MAF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 1707
# 單位: 1
# 漲停價: 158.0
# 跌停價: 130.0
# 參考價: 144.0
# 更新日期: 2025/03/20
# 目標代碼: MAFD5
# --------------------------------------------------
# 商品代碼: MBFR1
# 符號: MBFR1
# 名稱: 敬鵬期貨近月
# 類別: MBF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2355
# 單位: 1
# 漲停價: 40.25
# 跌停價: 32.95
# 參考價: 36.6
# 更新日期: 2025/03/20
# 目標代碼: MBFD5
# --------------------------------------------------
# 商品代碼: MJFR1
# 符號: MJFR1
# 名稱: 致茂期貨近月
# 類別: MJF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2360
# 單位: 1
# 漲停價: 342.5
# 跌停價: 280.5
# 參考價: 311.5
# 更新日期: 2025/03/20
# 目標代碼: MJFD5
# --------------------------------------------------
# 商品代碼: MKFR1
# 符號: MKFR1
# 名稱: 美律期貨近月
# 類別: MKF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2439
# 單位: 1
# 漲停價: 135.0
# 跌停價: 111.0
# 參考價: 123.0
# 更新日期: 2025/03/20
# 目標代碼: MKFD5
# --------------------------------------------------
# 商品代碼: MQFR1
# 符號: MQFR1
# 名稱: 矽格期貨近月
# 類別: MQF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 6257
# 單位: 1
# 漲停價: 85.3
# 跌停價: 69.9
# 參考價: 77.6
# 更新日期: 2025/03/20
# 目標代碼: MQFD5
# --------------------------------------------------
# 商品代碼: MVFR1
# 符號: MVFR1
# 名稱: 百和期貨近月
# 類別: MVF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 9938
# 單位: 1
# 漲停價: 73.1
# 跌停價: 59.9
# 參考價: 66.5
# 更新日期: 2025/03/20
# 目標代碼: MVFD5
# --------------------------------------------------
# 商品代碼: MX1R1
# 符號: MX1R1
# 名稱: 小型臺指04近月
# 類別: MX1
# 交割月份: 202504
# 交割日期: 2025/04/02
# 標的種類: I
# 標的代碼:
# 單位: 1
# 漲停價: 24236.0
# 跌停價: 19830.0
# 參考價: 22033.0
# 更新日期: 2025/03/20
# 目標代碼: MX1D5
# --------------------------------------------------
# 商品代碼: MX4R1
# 符號: MX4R1
# 名稱: 小型臺指03近月
# 類別: MX4
# 交割月份: 202503
# 交割日期: 2025/03/26
# 標的種類: I
# 標的代碼:
# 單位: 1
# 漲停價: 24227.0
# 跌停價: 19823.0
# 參考價: 22025.0
# 更新日期: 2025/03/20
# 目標代碼: MX4C5
# --------------------------------------------------
# 商品代碼: MXFR1
# 符號: MXFR1
# 名稱: 小型臺指近月
# 類別: MXF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: I
# 標的代碼:
# 單位: 1
# 漲停價: 24219.0
# 跌停價: 19817.0
# 參考價: 22018.0
# 更新日期: 2025/03/20
# 目標代碼: MXFD5
# --------------------------------------------------
# 商品代碼: MYFR1
# 符號: MYFR1
# 名稱: 精華期貨近月
# 類別: MYF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 1565
# 單位: 1
# 漲停價: 216.5
# 跌停價: 177.5
# 參考價: 197.0
# 更新日期: 2025/03/20
# 目標代碼: MYFD5
# --------------------------------------------------
# 商品代碼: NAFR1
# 符號: NAFR1
# 名稱: 穩懋期貨近月
# 類別: NAF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 3105
# 單位: 1
# 漲停價: 125.5
# 跌停價: 103.5
# 參考價: 114.5
# 更新日期: 2025/03/20
# 目標代碼: NAFD5
# --------------------------------------------------
# 商品代碼: NBFR1
# 符號: NBFR1
# 名稱: 璟德期貨近月
# 類別: NBF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 3152
# 單位: 1
# 漲停價: 172.5
# 跌停價: 141.5
# 參考價: 157.0
# 更新日期: 2025/03/20
# 目標代碼: NBFD5
# --------------------------------------------------
# 商品代碼: NDFR1
# 符號: NDFR1
# 名稱: 威剛期貨近月
# 類別: NDF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 3260
# 單位: 1
# 漲停價: 104.5
# 跌停價: 85.5
# 參考價: 95.0
# 更新日期: 2025/03/20
# 目標代碼: NDFD5
# --------------------------------------------------
# 商品代碼: NEFR1
# 符號: NEFR1
# 名稱: 欣銓期貨近月
# 類別: NEF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 3264
# 單位: 1
# 漲停價: 79.5
# 跌停價: 65.1
# 參考價: 72.3
# 更新日期: 2025/03/20
# 目標代碼: NEFD5
# --------------------------------------------------
# 商品代碼: NGFR1
# 符號: NGFR1
# 名稱: 碩禾期貨近月
# 類別: NGF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 3691
# 單位: 1
# 漲停價: 82.1
# 跌停價: 67.3
# 參考價: 74.7
# 更新日期: 2025/03/20
# 目標代碼: NGFD5
# --------------------------------------------------
# 商品代碼: NIFR1
# 符號: NIFR1
# 名稱: 晟德期貨近月
# 類別: NIF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 4123
# 單位: 1
# 漲停價: 44.0
# 跌停價: 36.0
# 參考價: 40.0
# 更新日期: 2025/03/20
# 目標代碼: NIFD5
# --------------------------------------------------
# 商品代碼: NJFR1
# 符號: NJFR1
# 名稱: 榮剛期貨近月
# 類別: NJF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 5009
# 單位: 1
# 漲停價: 54.1
# 跌停價: 44.35
# 參考價: 49.25
# 更新日期: 2025/03/20
# 目標代碼: NJFD5
# --------------------------------------------------
# 商品代碼: NKFR1
# 符號: NKFR1
# 名稱: 日經指近月
# 類別: NKF
# 交割月份: 202503
# 交割日期: 2025/03/20
# 標的種類: E
# 標的代碼:
# 單位: 1
# 漲停價: 0.0
# 跌停價: 0.0
# 參考價: 37510.0
# 更新日期: 2025/03/20
# 目標代碼: NKF5
# --------------------------------------------------
# 商品代碼: NKIR1
# 符號: NKIR1
# 名稱: 日經指近月
# 類別: NKI
# 交割月份: 202503
# 交割日期: 2025/03/20
# 標的種類: E
# 標的代碼:
# 單位: 1
# 漲停價: 0.0
# 跌停價: 0.0
# 參考價: 37495.0
# 更新日期: 2025/03/20
# 目標代碼: NKI5
# --------------------------------------------------
# 商品代碼: NKLR1
# 符號: NKLR1
# 名稱: 日經指近月
# 類別: NKL
# 交割月份: 202503
# 交割日期: 2025/03/20
# 標的種類: E
# 標的代碼:
# 單位: 1
# 漲停價: 0.0
# 跌停價: 0.0
# 參考價: 37290.0
# 更新日期: 2025/03/20
# 目標代碼: NKL5
# --------------------------------------------------
# 商品代碼: NLFR1
# 符號: NLFR1
# 名稱: 世界期貨近月
# 類別: NLF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 5347
# 單位: 1
# 漲停價: 104.5
# 跌停價: 85.5
# 參考價: 95.0
# 更新日期: 2025/03/20
# 目標代碼: NLFD5
# --------------------------------------------------
# 商品代碼: NMFR1
# 符號: NMFR1
# 名稱: 中光電期貨近月
# 類別: NMF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 5371
# 單位: 1
# 漲停價: 90.5
# 跌停價: 74.1
# 參考價: 82.3
# 更新日期: 2025/03/20
# 目標代碼: NMFD5
# --------------------------------------------------
# 商品代碼: NOFR1
# 符號: NOFR1
# 名稱: 中美晶期貨近月
# 類別: NOF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 5483
# 單位: 1
# 漲停價: 135.5
# 跌停價: 111.5
# 參考價: 123.5
# 更新日期: 2025/03/20
# 目標代碼: NOFD5
# --------------------------------------------------
# 商品代碼: NQFR1
# 符號: NQFR1
# 名稱: 新普期貨近月
# 類別: NQF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 6121
# 單位: 1
# 漲停價: 436.5
# 跌停價: 357.5
# 參考價: 397.0
# 更新日期: 2025/03/20
# 目標代碼: NQFD5
# --------------------------------------------------
# 商品代碼: NSFR1
# 符號: NSFR1
# 名稱: 頎邦期貨近月
# 類別: NSF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 6147
# 單位: 1
# 漲停價: 73.2
# 跌停價: 60.0
# 參考價: 66.6
# 更新日期: 2025/03/20
# 目標代碼: NSFD5
# --------------------------------------------------
# 商品代碼: NUFR1
# 符號: NUFR1
# 名稱: 網家期貨近月
# 類別: NUF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 8044
# 單位: 1
# 漲停價: 48.2
# 跌停價: 39.5
# 參考價: 43.85
# 更新日期: 2025/03/20
# 目標代碼: NUFD5
# --------------------------------------------------
# 商品代碼: NVFR1
# 符號: NVFR1
# 名稱: 元太期貨近月
# 類別: NVF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 8069
# 單位: 1
# 漲停價: 324.5
# 跌停價: 265.5
# 參考價: 295.0
# 更新日期: 2025/03/20
# 目標代碼: NVFD5
# --------------------------------------------------
# 商品代碼: NWFR1
# 符號: NWFR1
# 名稱: 群聯期貨近月
# 類別: NWF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 8299
# 單位: 1
# 漲停價: 654.0
# 跌停價: 536.0
# 參考價: 595.0
# 更新日期: 2025/03/20
# 目標代碼: NWFD5
# --------------------------------------------------
# 商品代碼: NYFR1
# 符號: NYFR1
# 名稱: 元大台灣50ETF期貨近月
# 類別: NYF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 0050
# 單位: 1
# 漲停價: 198.7
# 跌停價: 162.6
# 參考價: 180.65
# 更新日期: 2025/03/20
# 目標代碼: NYFD5
# --------------------------------------------------
# 商品代碼: OAFR1
# 符號: OAFR1
# 名稱: 富邦上証ETF期貨近月
# 類別: OAF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 006205S
# 單位: 1
# 漲停價: 39.81
# 跌停價: 29.43
# 參考價: 34.62
# 更新日期: 2025/03/20
# 目標代碼: OAFD5
# --------------------------------------------------
# 商品代碼: OBFR1
# 符號: OBFR1
# 名稱: 元大上證50ETF期貨近月
# 類別: OBF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 006206S
# 單位: 1
# 漲停價: 38.08
# 跌停價: 28.16
# 參考價: 33.12
# 更新日期: 2025/03/20
# 目標代碼: OBFD5
# --------------------------------------------------
# 商品代碼: ODFR1
# 符號: ODFR1
# 名稱: 為升期貨近月
# 類別: ODF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2231
# 單位: 1
# 漲停價: 99.5
# 跌停價: 81.5
# 參考價: 90.5
# 更新日期: 2025/03/20
# 目標代碼: ODFD5
# --------------------------------------------------
# 商品代碼: OEFR1
# 符號: OEFR1
# 名稱: 彩晶期貨近月
# 類別: OEF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 6116
# 單位: 1
# 漲停價: 9.41
# 跌停價: 7.71
# 參考價: 8.56
# 更新日期: 2025/03/20
# 目標代碼: OEFD5
# --------------------------------------------------
# 商品代碼: OHFR1
# 符號: OHFR1
# 名稱: 胡連期貨近月
# 類別: OHF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 6279
# 單位: 1
# 漲停價: 183.5
# 跌停價: 150.5
# 參考價: 167.0
# 更新日期: 2025/03/20
# 目標代碼: OHFD5
# --------------------------------------------------
# 商品代碼: OJFR1
# 符號: OJFR1
# 名稱: 國泰中國A50ETF期貨近月
# 類別: OJF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 00636
# 單位: 1
# 漲停價: 27.97
# 跌停價: 20.69
# 參考價: 24.33
# 更新日期: 2025/03/20
# 目標代碼: OJFD5
# --------------------------------------------------
# 商品代碼: OKFR1
# 符號: OKFR1
# 名稱: 富邦深100ETF期貨近月
# 類別: OKF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 00639
# 單位: 1
# 漲停價: 14.46
# 跌停價: 10.7
# 參考價: 12.58
# 更新日期: 2025/03/20
# 目標代碼: OKFD5
# --------------------------------------------------
# 商品代碼: OLFR1
# 符號: OLFR1
# 名稱: 小型大立光期貨近月
# 類別: OLF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 3008
# 單位: 1
# 漲停價: 2725.0
# 跌停價: 2235.0
# 參考價: 2480.0
# 更新日期: 2025/03/20
# 目標代碼: OLFD5
# --------------------------------------------------
# 商品代碼: OMFR1
# 符號: OMFR1
# 名稱: 小型精華期貨近月
# 類別: OMF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 1565
# 單位: 1
# 漲停價: 216.5
# 跌停價: 177.5
# 參考價: 197.0
# 更新日期: 2025/03/20
# 目標代碼: OMFD5
# --------------------------------------------------
# 商品代碼: OOFR1
# 符號: OOFR1
# 名稱: 群益深証中小ETF期貨近月
# 類別: OOF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 00643
# 單位: 1
# 漲停價: 16.24
# 跌停價: 12.02
# 參考價: 14.13
# 更新日期: 2025/03/20
# 目標代碼: OOFD5
# --------------------------------------------------
# 商品代碼: OPFR1
# 符號: OPFR1
# 名稱: 智邦期貨近月
# 類別: OPF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2345
# 單位: 1
# 漲停價: 712.0
# 跌停價: 584.0
# 參考價: 648.0
# 更新日期: 2025/03/20
# 目標代碼: OPFD5
# --------------------------------------------------
# 商品代碼: OQFR1
# 符號: OQFR1
# 名稱: 樺漢期貨近月
# 類別: OQF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 6414
# 單位: 1
# 漲停價: 328.5
# 跌停價: 269.5
# 參考價: 299.0
# 更新日期: 2025/03/20
# 目標代碼: OQFD5
# --------------------------------------------------
# 商品代碼: ORFR1
# 符號: ORFR1
# 名稱: 和大期貨近月
# 類別: ORF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 1536
# 單位: 1
# 漲停價: 78.4
# 跌停價: 64.2
# 參考價: 71.3
# 更新日期: 2025/03/20
# 目標代碼: ORFD5
# --------------------------------------------------
# 商品代碼: OSFR1
# 符號: OSFR1
# 名稱: 榮成期貨近月
# 類別: OSF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 1909
# 單位: 1
# 漲停價: 12.45
# 跌停價: 10.25
# 參考價: 11.35
# 更新日期: 2025/03/20
# 目標代碼: OSFD5
# --------------------------------------------------
# 商品代碼: OTFR1
# 符號: OTFR1
# 名稱: 聯亞期貨近月
# 類別: OTF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 3081
# 單位: 1
# 漲停價: 335.5
# 跌停價: 274.5
# 參考價: 305.0
# 更新日期: 2025/03/20
# 目標代碼: OTFD5
# --------------------------------------------------
# 商品代碼: OUFR1
# 符號: OUFR1
# 名稱: 同致期貨近月
# 類別: OUF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 3552
# 單位: 1
# 漲停價: 90.0
# 跌停價: 73.8
# 參考價: 81.9
# 更新日期: 2025/03/20
# 目標代碼: OUFD5
# --------------------------------------------------
# 商品代碼: OVFR1
# 符號: OVFR1
# 名稱: 台燿期貨近月
# 類別: OVF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 6274
# 單位: 1
# 漲停價: 185.0
# 跌停價: 152.0
# 參考價: 168.5
# 更新日期: 2025/03/20
# 目標代碼: OVFD5
# --------------------------------------------------
# 商品代碼: OWFR1
# 符號: OWFR1
# 名稱: 環球晶期貨近月
# 類別: OWF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 6488
# 單位: 1
# 漲停價: 415.0
# 跌停價: 340.0
# 參考價: 377.5
# 更新日期: 2025/03/20
# 目標代碼: OWFD5
# --------------------------------------------------
# 商品代碼: OXFR1
# 符號: OXFR1
# 名稱: 精測期貨近月
# 類別: OXF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 6510
# 單位: 1
# 漲停價: 754.0
# 跌停價: 618.0
# 參考價: 686.0
# 更新日期: 2025/03/20
# 目標代碼: OXFD5
# --------------------------------------------------
# 商品代碼: OYFR1
# 符號: OYFR1
# 名稱: 小型精測期貨近月
# 類別: OYF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 6510
# 單位: 1
# 漲停價: 754.0
# 跌停價: 618.0
# 參考價: 686.0
# 更新日期: 2025/03/20
# 目標代碼: OYFD5
# --------------------------------------------------
# 商品代碼: OZFR1
# 符號: OZFR1
# 名稱: 日月光投控期貨近月
# 類別: OZF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 3711
# 單位: 1
# 漲停價: 174.5
# 跌停價: 143.5
# 參考價: 159.0
# 更新日期: 2025/03/20
# 目標代碼: OZFD5
# --------------------------------------------------
# 商品代碼: PAFR1
# 符號: PAFR1
# 名稱: 原相期貨近月
# 類別: PAF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 3227
# 單位: 1
# 漲停價: 253.5
# 跌停價: 207.5
# 參考價: 230.5
# 更新日期: 2025/03/20
# 目標代碼: PAFD5
# --------------------------------------------------
# 商品代碼: PBFR1
# 符號: PBFR1
# 名稱: 小型環球晶期貨近月
# 類別: PBF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 6488
# 單位: 1
# 漲停價: 415.0
# 跌停價: 340.0
# 參考價: 377.5
# 更新日期: 2025/03/20
# 目標代碼: PBFD5
# --------------------------------------------------
# 商品代碼: PCFR1
# 符號: PCFR1
# 名稱: 智擎期貨近月
# 類別: PCF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 4162
# 單位: 1
# 漲停價: 115.5
# 跌停價: 94.5
# 參考價: 105.0
# 更新日期: 2025/03/20
# 目標代碼: PCFD5
# --------------------------------------------------
# 商品代碼: PDFR1
# 符號: PDFR1
# 名稱: 泰博期貨近月
# 類別: PDF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 4736
# 單位: 1
# 漲停價: 167.5
# 跌停價: 137.5
# 參考價: 152.5
# 更新日期: 2025/03/20
# 目標代碼: PDFD5
# --------------------------------------------------
# 商品代碼: PEFR1
# 符號: PEFR1
# 名稱: 台半期貨近月
# 類別: PEF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 5425
# 單位: 1
# 漲停價: 56.9
# 跌停價: 46.65
# 參考價: 51.8
# 更新日期: 2025/03/20
# 目標代碼: PEFD5
# --------------------------------------------------
# 商品代碼: PFFR1
# 符號: PFFR1
# 名稱: 元大高股息ETF期貨近月
# 類別: PFF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 0056
# 單位: 1
# 漲停價: 39.74
# 跌停價: 32.52
# 參考價: 36.13
# 更新日期: 2025/03/20
# 目標代碼: PFFD5
# --------------------------------------------------
# 商品代碼: PGFR1
# 符號: PGFR1
# 名稱: 台灣高鐵期貨近月
# 類別: PGF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2633
# 單位: 1
# 漲停價: 30.0
# 跌停價: 24.6
# 參考價: 27.3
# 更新日期: 2025/03/20
# 目標代碼: PGFD5
# --------------------------------------------------
# 商品代碼: PHFR1
# 符號: PHFR1
# 名稱: 祥碩期貨近月
# 類別: PHF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 5269
# 單位: 1
# 漲停價: 2230.0
# 跌停價: 1830.0
# 參考價: 2030.0
# 更新日期: 2025/03/20
# 目標代碼: PHFD5
# --------------------------------------------------
# 商品代碼: PIFR1
# 符號: PIFR1
# 名稱: 力旺期貨近月
# 類別: PIF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 3529
# 單位: 1
# 漲停價: 2790.0
# 跌停價: 2290.0
# 參考價: 2540.0
# 更新日期: 2025/03/20
# 目標代碼: PIFD5
# --------------------------------------------------
# 商品代碼: PJFR1
# 符號: PJFR1
# 名稱: 台光電期貨近月
# 類別: PJF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2383
# 單位: 1
# 漲停價: 644.0
# 跌停價: 528.0
# 參考價: 586.0
# 更新日期: 2025/03/20
# 目標代碼: PJFD5
# --------------------------------------------------
# 商品代碼: PKFR1
# 符號: PKFR1
# 名稱: 信昌電期貨近月
# 類別: PKF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 6173
# 單位: 1
# 漲停價: 47.95
# 跌停價: 39.25
# 參考價: 43.6
# 更新日期: 2025/03/20
# 目標代碼: PKFD5
# --------------------------------------------------
# 商品代碼: PLFR1
# 符號: PLFR1
# 名稱: 合晶期貨近月
# 類別: PLF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 6182
# 單位: 1
# 漲停價: 27.15
# 跌停價: 22.25
# 參考價: 24.7
# 更新日期: 2025/03/20
# 目標代碼: PLFD5
# --------------------------------------------------
# 商品代碼: PMFR1
# 符號: PMFR1
# 名稱: 大江期貨近月
# 類別: PMF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 8436
# 單位: 1
# 漲停價: 177.0
# 跌停價: 145.0
# 參考價: 161.0
# 更新日期: 2025/03/20
# 目標代碼: PMFD5
# --------------------------------------------------
# 商品代碼: PNFR1
# 符號: PNFR1
# 名稱: 小型祥碩期貨近月
# 類別: PNF
# 交割月份: 202504
# ...
# 標的代碼: 6443
# 單位: 1
# 漲停價: 21.35
# 跌停價: 17.55
# 參考價: 19.45
# 更新日期: 2025/03/20
# 目標代碼: RLFD5
# --------------------------------------------------
# 商品代碼: RMFR1
# 符號: RMFR1
# 名稱: 富邦媒期貨近月
# 類別: RMF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 8454
# 單位: 1
# 漲停價: 399.5
# 跌停價: 327.5
# 參考價: 363.5
# 更新日期: 2025/03/20
# 目標代碼: RMFD5
# --------------------------------------------------
# 商品代碼: RNFR1
# 符號: RNFR1
# 名稱: 合一期貨近月
# 類別: RNF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 4743
# 單位: 1
# 漲停價: 82.0
# 跌停價: 67.2
# 參考價: 74.6
# 更新日期: 2025/03/20
# 目標代碼: RNFD5
# --------------------------------------------------
# 商品代碼: ROFR1
# 符號: ROFR1
# 名稱: 立端期貨近月
# 類別: ROF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 6245
# 單位: 1
# 漲停價: 114.0
# 跌停價: 93.6
# 參考價: 104.0
# 更新日期: 2025/03/20
# 目標代碼: ROFD5
# --------------------------------------------------
# 商品代碼: RPFR1
# 符號: RPFR1
# 名稱: 寶雅期貨近月
# 類別: RPF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 5904
# 單位: 1
# 漲停價: 557.0
# 跌停價: 456.5
# 參考價: 507.0
# 更新日期: 2025/03/20
# 目標代碼: RPFD5
# --------------------------------------------------
# 商品代碼: RQFR1
# 符號: RQFR1
# 名稱: 小型富邦媒期貨近月
# 類別: RQF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 8454
# 單位: 1
# 漲停價: 399.5
# 跌停價: 327.5
# 參考價: 363.5
# 更新日期: 2025/03/20
# 目標代碼: RQFD5
# --------------------------------------------------
# 商品代碼: RRFR1
# 符號: RRFR1
# 名稱: 小型寶雅期貨近月
# 類別: RRF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 5904
# 單位: 1
# 漲停價: 557.0
# 跌停價: 456.5
# 參考價: 507.0
# 更新日期: 2025/03/20
# 目標代碼: RRFD5
# --------------------------------------------------
# 商品代碼: RSFR1
# 符號: RSFR1
# 名稱: 小型力旺期貨近月
# 類別: RSF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 3529
# 單位: 1
# 漲停價: 2790.0
# 跌停價: 2290.0
# 參考價: 2540.0
# 更新日期: 2025/03/20
# 目標代碼: RSFD5
# --------------------------------------------------
# 商品代碼: RTFR1
# 符號: RTFR1
# 名稱: 小型美元兌人民幣期貨近月
# 類別: RTF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: E
# 標的代碼:
# 單位: 1
# 漲停價: 7.442
# 跌停價: 7.0086
# 參考價: 7.2253
# 更新日期: 2025/03/20
# 目標代碼: RTFD5
# --------------------------------------------------
# 商品代碼: RUFR1
# 符號: RUFR1
# 名稱: 世紀鋼期貨近月
# 類別: RUF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 9958
# 單位: 1
# 漲停價: 202.5
# 跌停價: 166.5
# 參考價: 184.5
# 更新日期: 2025/03/20
# 目標代碼: RUFD5
# --------------------------------------------------
# 商品代碼: RVFR1
# 符號: RVFR1
# 名稱: 小型台達電期貨近月
# 類別: RVF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2308
# 單位: 1
# 漲停價: 432.5
# 跌停價: 354.5
# 參考價: 393.5
# 更新日期: 2025/03/20
# 目標代碼: RVFD5
# --------------------------------------------------
# 商品代碼: RWFR1
# 符號: RWFR1
# 名稱: 小型創意期貨近月
# 類別: RWF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 3443
# 單位: 1
# 漲停價: 1280.0
# 跌停價: 1050.0
# 參考價: 1165.0
# 更新日期: 2025/03/20
# 目標代碼: RWFD5
# --------------------------------------------------
# 商品代碼: RXFR1
# 符號: RXFR1
# 名稱: 富邦越南ETF期貨近月
# 類別: RXF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 00885
# 單位: 1
# 漲停價: 14.27
# 跌停價: 10.55
# 參考價: 12.41
# 更新日期: 2025/03/20
# 目標代碼: RXFD5
# --------------------------------------------------
# 商品代碼: RYFR1
# 符號: RYFR1
# 名稱: 群益台ESG低碳50ETF期貨近月
# 類別: RYF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 00923
# 單位: 1
# 漲停價: 22.59
# 跌停價: 18.49
# 參考價: 20.54
# 更新日期: 2025/03/20
# 目標代碼: RYFD5
# --------------------------------------------------
# 商品代碼: RZFR1
# 符號: RZFR1
# 名稱: 元大美債20年ETF期貨近月
# 類別: RZF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 00679BS
# 單位: 1
# 漲停價: 34.07
# 跌停價: 25.19
# 參考價: 29.63
# 更新日期: 2025/03/20
# 目標代碼: RZFD5
# --------------------------------------------------
# 商品代碼: SAFR1
# 符號: SAFR1
# 名稱: 美時期貨近月
# 類別: SAF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 1795
# 單位: 1
# 漲停價: 277.0
# 跌停價: 227.0
# 參考價: 252.0
# 更新日期: 2025/03/20
# 目標代碼: SAFD5
# --------------------------------------------------
# 商品代碼: SBFR1
# 符號: SBFR1
# 名稱: 華紙期貨近月
# 類別: SBF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 1905
# 單位: 1
# 漲停價: 18.55
# 跌停價: 15.25
# 參考價: 16.9
# 更新日期: 2025/03/20
# 目標代碼: SBFD5
# --------------------------------------------------
# 商品代碼: SCFR1
# 符號: SCFR1
# 名稱: 小型聚陽期貨近月
# 類別: SCF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 1477
# 單位: 1
# 漲停價: 367.5
# 跌停價: 301.5
# 參考價: 334.5
# 更新日期: 2025/03/20
# 目標代碼: SCFD5
# --------------------------------------------------
# 商品代碼: SDFR1
# 符號: SDFR1
# 名稱: 中興電期貨近月
# 類別: SDF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 1513
# 單位: 1
# 漲停價: 157.0
# 跌停價: 129.0
# 參考價: 143.0
# 更新日期: 2025/03/20
# 目標代碼: SDFD5
# --------------------------------------------------
# 商品代碼: SEFR1
# 符號: SEFR1
# 名稱: 小型智邦期貨近月
# 類別: SEF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2345
# 單位: 1
# 漲停價: 712.0
# 跌停價: 584.0
# 參考價: 648.0
# 更新日期: 2025/03/20
# 目標代碼: SEFD5
# --------------------------------------------------
# 商品代碼: SFFR1
# 符號: SFFR1
# 名稱: 小型台光電期貨近月
# 類別: SFF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2383
# 單位: 1
# 漲停價: 644.0
# 跌停價: 528.0
# 參考價: 586.0
# 更新日期: 2025/03/20
# 目標代碼: SFFD5
# --------------------------------------------------
# 商品代碼: SGFR1
# 符號: SGFR1
# 名稱: 國泰智能電動車ETF期貨近月
# 類別: SGF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 00893
# 單位: 1
# 漲停價: 25.86
# 跌停價: 19.12
# 參考價: 22.49
# 更新日期: 2025/03/20
# 目標代碼: SGFD5
# --------------------------------------------------
# 商品代碼: SHFR1
# 符號: SHFR1
# 名稱: 航運期貨近月
# 類別: SHF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: I
# 標的代碼:
# 單位: 1
# 漲停價: 227.95
# 跌停價: 186.55
# 參考價: 207.25
# 更新日期: 2025/03/20
# 目標代碼: SHFD5
# --------------------------------------------------
# 商品代碼: SIFR1
# 符號: SIFR1
# 名稱: 元大美債1-3ETF期貨近月
# 類別: SIF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 00719BS
# 單位: 1
# 漲停價: 37.54
# 跌停價: 27.76
# 參考價: 32.65
# 更新日期: 2025/03/20
# 目標代碼: SIFD5
# --------------------------------------------------
# 商品代碼: SJFR1
# 符號: SJFR1
# 名稱: 神基期貨近月
# 類別: SJF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 3005
# 單位: 1
# 漲停價: 124.5
# 跌停價: 102.5
# 參考價: 113.5
# 更新日期: 2025/03/20
# 目標代碼: SJFD5
# --------------------------------------------------
# 商品代碼: SKFR1
# 符號: SKFR1
# 名稱: 至上期貨近月
# 類別: SKF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 8112
# 單位: 1
# 漲停價: 66.8
# 跌停價: 54.8
# 參考價: 60.8
# 更新日期: 2025/03/20
# 目標代碼: SKFD5
# --------------------------------------------------
# 商品代碼: SLFR1
# 符號: SLFR1
# 名稱: 小型技嘉期貨近月
# 類別: SLF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2376
# 單位: 1
# 漲停價: 289.0
# 跌停價: 237.0
# 參考價: 263.0
# 更新日期: 2025/03/20
# 目標代碼: SLFD5
# --------------------------------------------------
# 商品代碼: SMFR1
# 符號: SMFR1
# 名稱: 群益台灣精選高息ETF期貨近月
# 類別: SMF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 00919
# 單位: 1
# 漲停價: 25.33
# 跌停價: 20.73
# 參考價: 23.03
# 更新日期: 2025/03/20
# 目標代碼: SMFD5
# --------------------------------------------------
# 商品代碼: SNFR1
# 符號: SNFR1
# 名稱: 復華台灣科技優息ETF期貨近月
# 類別: SNF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 00929
# 單位: 1
# 漲停價: 20.16
# 跌停價: 16.5
# 參考價: 18.33
# 更新日期: 2025/03/20
# 目標代碼: SNFD5
# --------------------------------------------------
# 商品代碼: SOFR1
# 符號: SOFR1
# 名稱: 半導體30期貨近月
# 類別: SOF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: I
# 標的代碼:
# 單位: 1
# 漲停價: 6574.0
# 跌停價: 5380.0
# 參考價: 5977.0
# 更新日期: 2025/03/20
# 目標代碼: SOFD5
# --------------------------------------------------
# 商品代碼: SPFR1
# 符號: SPFR1
# 名稱: 美國標普500期貨近月
# 類別: SPF
# 交割月份: 202503
# 交割日期: 2025/03/24
# 標的種類: I
# 標的代碼:
# 單位: 1
# 漲停價: 6022.0
# 跌停價: 5234.5
# 參考價: 5628.25
# 更新日期: 2025/03/20
# 目標代碼: SPFC5
# --------------------------------------------------
# 商品代碼: SQFR1
# 符號: SQFR1
# 名稱: 中信高評級公司債ETF期貨近月
# 類別: SQF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 00772BS
# 單位: 1
# 漲停價: 41.22
# 跌停價: 30.48
# 參考價: 35.85
# 更新日期: 2025/03/20
# 目標代碼: SQFD5
# --------------------------------------------------
# 商品代碼: SRFR1
# 符號: SRFR1
# 名稱: 小型元大台灣50ETF期貨近月
# 類別: SRF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 0050
# 單位: 1
# 漲停價: 198.7
# 跌停價: 162.6
# 參考價: 180.65
# 更新日期: 2025/03/20
# 目標代碼: SRFD5
# --------------------------------------------------
# 商品代碼: SSFR1
# 符號: SSFR1
# 名稱: 小型元大高股息ETF期貨近月
# 類別: SSF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 0056
# 單位: 1
# 漲停價: 39.74
# 跌停價: 32.52
# 參考價: 36.13
# 更新日期: 2025/03/20
# 目標代碼: SSFD5
# --------------------------------------------------
# 商品代碼: SUFR1
# 符號: SUFR1
# 名稱: 元大台灣價值高息ETF期貨近月
# 類別: SUF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 00940
# 單位: 1
# 漲停價: 10.38
# 跌停價: 8.5
# 參考價: 9.44
# 更新日期: 2025/03/20
# 目標代碼: SUFD5
# --------------------------------------------------
# 商品代碼: SVFR1
# 符號: SVFR1
# 名稱: 小型川湖期貨近月
# 類別: SVF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 2059
# 單位: 1
# 漲停價: 2120.0
# 跌停價: 1740.0
# 參考價: 1930.0
# 更新日期: 2025/03/20
# 目標代碼: SVFD5
# --------------------------------------------------
# 商品代碼: SWFR1
# 符號: SWFR1
# 名稱: 小型世紀鋼期貨近月
# 類別: SWF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 9958
# 單位: 1
# 漲停價: 202.5
# 跌停價: 166.5
# 參考價: 184.5
# 更新日期: 2025/03/20
# 目標代碼: SWFD5
# --------------------------------------------------
# 商品代碼: SXFR1
# 符號: SXFR1
# 名稱: 美國費城半導體期貨近月
# 類別: SXF
# 交割月份: 202503
# 交割日期: 2025/03/24
# 標的種類: I
# 標的代碼:
# 單位: 1
# 漲停價: 4930.5
# 跌停價: 4285.5
# 參考價: 4608.0
# 更新日期: 2025/03/20
# 目標代碼: SXFC5
# --------------------------------------------------
# 商品代碼: SYFR1
# 符號: SYFR1
# 名稱: 家登期貨近月
# 類別: SYF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 3680
# 單位: 1
# 漲停價: 445.5
# 跌停價: 364.5
# 參考價: 405.0
# 更新日期: 2025/03/20
# 目標代碼: SYFD5
# --------------------------------------------------
# 商品代碼: SZFR1
# 符號: SZFR1
# 名稱: 小型家登期貨近月
# 類別: SZF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 3680
# 單位: 1
# 漲停價: 445.5
# 跌停價: 364.5
# 參考價: 405.0
# 更新日期: 2025/03/20
# 目標代碼: SZFD5
# --------------------------------------------------
# 商品代碼: TGFR1
# 符號: TGFR1
# 名稱: 臺幣黃金期貨近月
# 類別: TGF
# 交割月份: 202504
# 交割日期: 2025/04/29
# 標的種類: C
# 標的代碼:
# 單位: 1
# 漲停價: 12773.0
# 跌停價: 11557.0
# 參考價: 12165.0
# 更新日期: 2025/03/20
# 目標代碼: TGFD5
# --------------------------------------------------
# 商品代碼: TJFR1
# 符號: TJFR1
# 名稱: 東證期貨近月
# 類別: TJF
# 交割月份: 202504
# 交割日期: 2025/04/11
# 標的種類: I
# 標的代碼:
# 單位: 1
# 漲停價: 2985.5
# 跌停價: 2543.5
# 參考價: 2764.5
# 更新日期: 2025/03/20
# 目標代碼: TJFD5
# --------------------------------------------------
# 商品代碼: TMFR1
# 符號: TMFR1
# 名稱: 微型臺指期貨近月
# 類別: TMF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: I
# 標的代碼:
# 單位: 1
# 漲停價: 24219.0
# 跌停價: 19817.0
# 參考價: 22018.0
# 更新日期: 2025/03/20
# 目標代碼: TMFD5
# --------------------------------------------------
# 商品代碼: TWNR1
# 符號: TWNR1
# 名稱: 富時指近月
# 類別: TWN
# 交割月份: 202503
# 交割日期: 2025/03/20
# 標的種類: E
# 標的代碼:
# 單位: 1
# 漲停價: 0.0
# 跌停價: 0.0
# 參考價: 1845.25
# 更新日期: 2025/03/20
# 目標代碼: TWNF5
# --------------------------------------------------
# 商品代碼: TXFR1
# 符號: TXFR1
# 名稱: 臺股期貨近月
# 類別: TXF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: I
# 標的代碼:
# 單位: 1
# 漲停價: 24219.0
# 跌停價: 19817.0
# 參考價: 22018.0
# 更新日期: 2025/03/20
# 目標代碼: TXFD5
# --------------------------------------------------
# 商品代碼: UAFR1
# 符號: UAFR1
# 名稱: 士電期貨近月
# 類別: UAF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 1503
# 單位: 1
# 漲停價: 186.0
# 跌停價: 153.0
# 參考價: 169.5
# 更新日期: 2025/03/20
# 目標代碼: UAFD5
# --------------------------------------------------
# 商品代碼: UBFR1
# 符號: UBFR1
# 名稱: 亞翔期貨近月
# 類別: UBF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 6139
# 單位: 1
# 漲停價: 283.5
# 跌停價: 232.5
# 參考價: 258.0
# 更新日期: 2025/03/20
# 目標代碼: UBFD5
# --------------------------------------------------
# 商品代碼: UCFR1
# 符號: UCFR1
# 名稱: 廣明期貨近月
# 類別: UCF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 6188
# 單位: 1
# 漲停價: 110.5
# 跌停價: 90.5
# 參考價: 100.5
# 更新日期: 2025/03/20
# 目標代碼: UCFD5
# --------------------------------------------------
# 商品代碼: UDFR1
# 符號: UDFR1
# 名稱: 美國道瓊期貨近月
# 類別: UDF
# 交割月份: 202503
# 交割日期: 2025/03/24
# 標的種類: I
# 標的代碼:
# 單位: 1
# 漲停價: 44552.0
# 跌停價: 38724.0
# 參考價: 41638.0
# 更新日期: 2025/03/20
# 目標代碼: UDFC5
# --------------------------------------------------
# 商品代碼: UEFR1
# 符號: UEFR1
# 名稱: 上海商銀期貨近月
# 類別: UEF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 5876
# 單位: 1
# 漲停價: 49.1
# 跌停價: 40.2
# 參考價: 44.65
# 更新日期: 2025/03/20
# 目標代碼: UEFD5
# --------------------------------------------------
# 商品代碼: UFFR1
# 符號: UFFR1
# 名稱: 台塑化期貨近月
# 類別: UFF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 6505
# 單位: 1
# 漲停價: 43.8
# 跌停價: 35.9
# 參考價: 39.85
# 更新日期: 2025/03/20
# 目標代碼: UFFD5
# --------------------------------------------------
# 商品代碼: UGFR1
# 符號: UGFR1
# 名稱: 達發期貨近月
# 類別: UGF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 6526
# 單位: 1
# 漲停價: 679.0
# 跌停價: 557.0
# 參考價: 618.0
# 更新日期: 2025/03/20
# 目標代碼: UGFD5
# --------------------------------------------------
# 商品代碼: UHFR1
# 符號: UHFR1
# 名稱: 小型奇鋐期貨近月
# 類別: UHF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 3017
# 單位: 1
# 漲停價: 588.0
# 跌停價: 481.5
# 參考價: 535.0
# 更新日期: 2025/03/20
# 目標代碼: UHFD5
# --------------------------------------------------
# 商品代碼: UIFR1
# 符號: UIFR1
# 名稱: 小型達發期貨近月
# 類別: UIF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 6526
# 單位: 1
# 漲停價: 679.0
# 跌停價: 557.0
# 參考價: 618.0
# 更新日期: 2025/03/20
# 目標代碼: UIFD5
# --------------------------------------------------
# 商品代碼: UJFR1
# 符號: UJFR1
# 名稱: 群益ESG投等債20+ETF期貨近月
# 類別: UJF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 00937BS
# 單位: 1
# 漲停價: 18.35
# 跌停價: 13.57
# 參考價: 15.96
# 更新日期: 2025/03/20
# 目標代碼: UJFD5
# --------------------------------------------------
# 商品代碼: UKFR1
# 符號: UKFR1
# 名稱: 國泰20年美債ETF期貨近月
# 類別: UKF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 00687BS
# 單位: 1
# 漲停價: 35.37
# 跌停價: 26.15
# 參考價: 30.76
# 更新日期: 2025/03/20
# 目標代碼: UKFD5
# --------------------------------------------------
# 商品代碼: ULFR1
# 符號: ULFR1
# 名稱: 小型雙鴻期貨近月
# 類別: ULF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 3324
# 單位: 1
# 漲停價: 649.0
# 跌停價: 531.0
# 參考價: 590.0
# 更新日期: 2025/03/20
# 目標代碼: ULFD5
# --------------------------------------------------
# 商品代碼: UMFR1
# 符號: UMFR1
# 名稱: 世芯-KY期貨近月
# 類別: UMF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 3661
# 單位: 1
# 漲停價: 3135.0
# 跌停價: 2565.0
# 參考價: 2850.0
# 更新日期: 2025/03/20
# 目標代碼: UMFD5
# --------------------------------------------------
# 商品代碼: UNFR1
# 符號: UNFR1
# 名稱: 美國那斯達克100期貨近月
# 類別: UNF
# 交割月份: 202503
# 交割日期: 2025/03/24
# 標的種類: I
# 標的代碼:
# 單位: 1
# 漲停價: 20913.0
# 跌停價: 18177.0
# 參考價: 19545.0
# 更新日期: 2025/03/20
# 目標代碼: UNFC5
# --------------------------------------------------
# 商品代碼: UOFR1
# 符號: UOFR1
# 名稱: 小型世芯-KY期貨近月
# 類別: UOF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 3661
# 單位: 1
# 漲停價: 3135.0
# 跌停價: 2565.0
# 參考價: 2850.0
# 更新日期: 2025/03/20
# 目標代碼: UOFD5
# --------------------------------------------------
# 商品代碼: UPFR1
# 符號: UPFR1
# 名稱: 保瑞期貨近月
# 類別: UPF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 6472
# 單位: 1
# 漲停價: 842.0
# 跌停價: 690.0
# 參考價: 766.0
# 更新日期: 2025/03/20
# 目標代碼: UPFD5
# --------------------------------------------------
# 商品代碼: UQFR1
# 符號: UQFR1
# 名稱: 小型保瑞期貨近月
# 類別: UQF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 6472
# 單位: 1
# 漲停價: 842.0
# 跌停價: 690.0
# 參考價: 766.0
# 更新日期: 2025/03/20
# 目標代碼: UQFD5
# --------------------------------------------------
# 商品代碼: URFR1
# 符號: URFR1
# 名稱: 統一FANG+ETF期貨近月
# 類別: URF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 00757
# 單位: 1
# 漲停價: 107.5
# 跌停價: 79.5
# 參考價: 93.5
# 更新日期: 2025/03/20
# 目標代碼: URFD5
# --------------------------------------------------
# 商品代碼: USFR1
# 符號: USFR1
# 名稱: 小型統一FANG+ETF期貨近月
# 類別: USF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: S
# 標的代碼: 00757
# 單位: 1
# 漲停價: 107.5
# 跌停價: 79.5
# 參考價: 93.5
# 更新日期: 2025/03/20
# 目標代碼: USFD5
# --------------------------------------------------
# 商品代碼: XAFR1
# 符號: XAFR1
# 名稱: 澳幣兌美元期貨近月
# 類別: XAF
# 交割月份: 202506
# 交割日期: 2025/06/18
# 標的種類: E
# 標的代碼:
# 單位: 1
# 漲停價: 0.6531
# 跌停價: 0.6151
# 參考價: 0.6341
# 更新日期: 2025/03/20
# 目標代碼: XAFF5
# --------------------------------------------------
# 商品代碼: XBFR1
# 符號: XBFR1
# 名稱: 英鎊兌美元期貨近月
# 類別: XBF
# 交割月份: 202506
# 交割日期: 2025/06/18
# 標的種類: E
# 標的代碼:
# 單位: 1
# 漲停價: 1.336
# 跌停價: 1.2582
# 參考價: 1.2971
# 更新日期: 2025/03/20
# 目標代碼: XBFF5
# --------------------------------------------------
# 商品代碼: XEFR1
# 符號: XEFR1
# 名稱: 歐元兌美元期貨近月
# 類別: XEF
# 交割月份: 202506
# 交割日期: 2025/06/18
# 標的種類: E
# 標的代碼:
# 單位: 1
# 漲停價: 1.1283
# 跌停價: 1.0627
# 參考價: 1.0955
# 更新日期: 2025/03/20
# 目標代碼: XEFF5
# --------------------------------------------------
# 商品代碼: XIFR1
# 符號: XIFR1
# 名稱: 非金電期貨近月
# 類別: XIF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: I
# 標的代碼:
# 單位: 1
# 漲停價: 16270.0
# 跌停價: 13312.0
# 參考價: 14791.0
# 更新日期: 2025/03/20
# 目標代碼: XIFD5
# --------------------------------------------------
# 商品代碼: XJFR1
# 符號: XJFR1
# 名稱: 美元兌日圓期貨近月
# 類別: XJF
# 交割月份: 202506
# 交割日期: 2025/06/18
# 標的種類: E
# 標的代碼:
# 單位: 1
# 漲停價: 152.25
# 跌停價: 143.39
# 參考價: 147.82
# 更新日期: 2025/03/20
# 目標代碼: XJFF5
# --------------------------------------------------
# 商品代碼: YMCR1
# 符號: YMCR1
# 名稱: MI道瓊近月
# 類別: YMC
# 交割月份: 202503
# 交割日期: 2025/03/20
# 標的種類: E
# 標的代碼:
# 單位: 1
# 漲停價: 0.0
# 跌停價: 0.0
# 參考價: 41995.0
# 更新日期: 2025/03/20
# 目標代碼: YMC5
# --------------------------------------------------
# 商品代碼: YMFR1
# 符號: YMFR1
# 名稱: MI道瓊近月
# 類別: YMF
# 交割月份: 202503
# 交割日期: 2025/03/20
# 標的種類: E
# 標的代碼:
# 單位: 1
# 漲停價: 0.0
# 跌停價: 0.0
# 參考價: 42330.0
# 更新日期: 2025/03/20
# 目標代碼: YMF5
# --------------------------------------------------
# 商品代碼: YMIR1
# 符號: YMIR1
# 名稱: MI道瓊近月
# 類別: YMI
# 交割月份: 202503
# 交割日期: 2025/03/20
# 標的種類: E
# 標的代碼:
# 單位: 1
# 漲停價: 0.0
# 跌停價: 0.0
# 參考價: 42635.0
# 更新日期: 2025/03/20
# 目標代碼: YMI5
# --------------------------------------------------
# 商品代碼: YMLR1
# 符號: YMLR1
# 名稱: MI道瓊近月
# 類別: YML
# 交割月份: 202503
# 交割日期: 2025/03/20
# 標的種類: E
# 標的代碼:
# 單位: 1
# 漲停價: 0.0
# 跌停價: 0.0
# 參考價: 42952.0
# 更新日期: 2025/03/20
# 目標代碼: YML5
# --------------------------------------------------
# 商品代碼: ZEFR1
# 符號: ZEFR1
# 名稱: 小型電子期貨近月
# 類別: ZEF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: I
# 標的代碼:
# 單位: 1
# 漲停價: 1301.55
# 跌停價: 1064.95
# 參考價: 1183.25
# 更新日期: 2025/03/20
# 目標代碼: ZEFD5
# --------------------------------------------------
# 商品代碼: ZFFR1
# 符號: ZFFR1
# 名稱: 小型金融期貨近月
# 類別: ZFF
# 交割月份: 202504
# 交割日期: 2025/04/16
# 標的種類: I
# 標的代碼:
# 單位: 1
# 漲停價: 2360.2
# 跌停價: 1931.4
# 參考價: 2145.8
# 更新日期: 2025/03/20
# 目標代碼: ZFFD5
# --------------------------------------------------
# _block 沒有近月合約數據
# _code2contract 沒有近月合約數據
# _fetched 沒有近月合約數據
# _max_page 沒有近月合約數據
# _page_list 沒有近月合約數據
# append 沒有近月合約數據
# get 沒有近月合約數據
# keys 沒有近月合約數據
# post_init 沒有近月合約數據
# set_status_fetched 沒有近月合約數據

# %%
print(api.Contracts.Indexs.TSE)

for i in range(1, 100):
    contract_code = f"{i:03}"  # 格式化為三位數字
    contract = api.Contracts.Indexs.TSE.get(contract_code)  # 使用 get() 方法避免 KeyError
    if contract and hasattr(contract, 'name'):  # 確保 contract 存在且有 name 屬性
        print(contract.name)
    else:
        print(f"Contract TSE{contract_code} not found.")
# Out:
# TSE(TSE001, TSE002, TSE003, TSE004, TSE005, TSE006, TSE007, TSE008, TSE009, TSE010, TSE011, TSE012, TSE014, TSE015, TSE016, TSE017, TSE018, TSE019, TSE020, TSE021, TSE022, TSE023, TSE024, TSE025, TSE026, TSE027, TSE028, TSE029, TSE030, TSE031, TSE032, TSE033, TSE034, TSE035, TSE036, TSE037, TSE038, TSE039, TSE040, TSE041, TSE042, TSE043, TSE046, TSE047, TSE048, TSE049, TSE050, TSE051, TSE052, TSE053, TSE054, TSE055, TSE056, TSE057, TSE058, TSE059, TSE060, TSE061, TSE062, TSE064, TSE066, TSE067, TSE068, TSE069, TSE070, TSE071, TSE072, TSE073, TSE074, TSE076, TSE077, TSE079, TSE082, TSE083, TSE084, TSE085, TSE087, TSE088, TSE089, TSE090, TSE091, TSE092, TSE093, TSE094, TSE095, TSE096, TSE097, TSE098, TSE099)
# 加權指數
# 不含金融指數
# 不含電子指數
# 化學工業
# 生技醫療業
# 水泥窯製
# 食品類股
# 塑膠化工
# 紡織纖維
# 機電類
# 造紙類
# 建材營造類指數
# Contract TSE013 not found.
# 金融保險類指數
# 水泥工業
# 食品工業
# 塑膠工業
# 紡織纖維
# 電機機械
# 電器電纜
# 化學生技醫療
# 玻璃陶瓷
# 造紙工業
# 鋼鐵工業
# 橡膠工業
# 汽車工業
# 電子工業
# 建材營造
# 航運業
# 觀光事業
# 金融保險
# 貿易百貨
# 其他
# 未含金電股發行量加權股價指數
# 油電燃氣業
# 半導體業
# 電腦及週邊設備業
# 光電業
# 通信網路業
# 電子零組件業
# 電子通路業
# 資訊服務業
# 其他電子業
# Contract TSE044 not found.
# Contract TSE045 not found.
# 低碳高息40指數
# 成長高股息指數
# 工業4.0指數
# 半導體收益指數
# 臺灣上市上櫃多因子優選成長30指數
# 臺灣上市上櫃IC設計報酬指數
# 台灣上市上櫃永續價值指數
# 臺灣上市上櫃企業社會責任中小型指數
# 特選大蘋果報酬反向一倍指數
# 特選大蘋果報酬正向兩倍指數
# 智慧投資多因子30報酬指數
# 智慧投資多因子30指數
# 加權指數掩護性臺指買權價外5％報酬指數
# 台股期貨指數
# 智慧中立指數
# 勞工權益指數
# 電子菁英30報酬指數
# Contract TSE063 not found.
# 臺灣上市500大報酬指數
# Contract TSE065 not found.
# 中小型300報酬指數
# 中小型300指數
# 特選大蘋果報酬指數
# 存股雙十等權重報酬指數
# 漲升股利150報酬指數
# 臺灣中小型公司治理指數
# 臺灣IPO指數
# 價值投資指數
# 臺灣永續指數
# Contract TSE075 not found.
# 特選高息低波指數
# 臺灣生技指數
# Contract TSE078 not found.
# 中小型A級動能50指數
# Contract TSE080 not found.
# Contract TSE081 not found.
# 低波動股利精選30指數
# 電子菁英30指數
# 工業菁英30指數
# 藍籌30指數
# Contract TSE086 not found.
# 漲升股利150指數
# 小型股300指數
# 臺灣公司治理100指數
# 電子類反向指數
# 電子類兩倍槓桿指數
# 臺灣高薪100指數
# 寶島股價指數
# 臺灣就業99指數
# 臺灣中型100指數
# 臺灣資訊科技指數
# 臺灣發達指數
# 台灣高股息指數
# 台灣50指數
